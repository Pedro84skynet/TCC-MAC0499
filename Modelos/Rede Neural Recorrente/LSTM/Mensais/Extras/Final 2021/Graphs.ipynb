# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import mean_absolute_error

# %%
df_registered = pd.read_csv('registrado.csv')
df_registered.set_index('Registrado (mil ton.)', inplace=True)
df_registered = df_registered.T
df_registered
# Out:
# Registrado (mil ton.)    Acre  Alagoas   Amapá  Amazonas    Bahia    Ceara  \
# 2019-01                11.188   32.388   9.691    42.731  291.428  151.601
# 2019-02                10.381   30.378   7.378    36.026  249.430  129.537
# 2019-03                 8.080   30.641   6.970    34.609  241.612  105.236
# 2019-04                11.154   32.337   7.612    40.787  252.303  110.835
# 2019-05                12.508   36.405   8.442    39.823  281.912  127.925
# 2019-06                12.126   22.499   8.835    39.957  200.213  127.138
# 2019-07                14.496   27.961  11.251    52.048  270.511  157.128
# 2019-08                16.723   32.378  11.342    53.567  281.466  164.440
# 2019-09                15.253   32.582  13.110    46.239  285.535  140.298
# 2019-10                16.531   42.703  13.195    51.066  328.259  168.407
# 2019-11                15.206   38.584  10.053    51.684  298.078  163.615
# 2019-12                10.160   36.503  12.274    44.907  264.838  155.070
#
# Registrado (mil ton.)  Distrito Federal  Espirito Santo   Goiais  Maranhão  \
# 2019-01                          48.990         111.377  178.918    70.660
# 2019-02                          44.726          98.614  161.936    50.796
# 2019-03                          44.491          94.022  173.792    47.834
# 2019-04                          43.901          91.546  176.627    45.327
# 2019-05                          55.019          95.674  207.991    54.032
# 2019-06                          50.942          88.927  185.784    60.657
# 2019-07                          63.992         105.688  234.176    67.250
# 2019-08                          64.127         104.711  226.996    70.773
# 2019-09                          60.822          97.530  218.141    67.010
# 2019-10                          65.182          99.651  234.939    81.128
# 2019-11                          51.282          76.710  199.619    81.737
# 2019-12                          43.554          75.456  168.797    76.841
#
# Registrado (mil ton.)  ...   Piauí  Rio Grande do Sul  Rio de Janeiro  \
# 2019-01                ...  57.142            226.547         232.609
# 2019-02                ...  46.283            228.500         195.364
# 2019-03                ...  43.390            223.896         205.690
# 2019-04                ...  40.824            234.132         231.354
# 2019-05                ...  55.063            207.586         236.711
# 2019-06                ...  56.474            228.583         215.360
# 2019-07                ...  68.133            234.565         258.015
# 2019-08                ...  68.642            249.519         244.870
# 2019-09                ...  64.741            230.086         225.410
# 2019-10                ...  71.269            233.136         252.849
# 2019-11                ...  67.631            233.800         226.618
# 2019-12                ...  62.845            223.214         190.993
#
# Registrado (mil ton.)  Rio Grande do Norte  Rondônia  Roraima  Santa Catarina  \
# 2019-01                             46.081    32.559    9.908         252.700
# 2019-02                             38.703    24.910   10.723         246.146
# 2019-03                             36.037    28.713   10.625         255.873
# 2019-04                             38.430    32.660   10.593         273.299
# 2019-05                             44.471    31.635   10.681         270.918
# 2019-06                             37.884    35.142    7.887         256.605
# 2019-07                             51.585    36.419    9.751         303.526
# 2019-08                             54.306    40.300    9.654         299.284
# 2019-09                             52.511    35.493    9.422         284.550
# 2019-10                             59.472    38.489   11.160         307.576
# 2019-11                             54.022    35.591   10.491         281.317
# 2019-12                             49.791    27.530   10.225         226.233
#
# Registrado (mil ton.)  São Paulo  Sergipe  Tocantins
# 2019-01                  860.232   36.567     31.615
# 2019-02                  773.607   30.849     30.275
# 2019-03                  790.146   31.021     29.568
# 2019-04                  886.929   31.437     26.940
# 2019-05                  941.600   31.533     35.910
# 2019-06                  817.301   26.431     33.954
# 2019-07                  957.289   25.978     37.983
# 2019-08                  978.990   29.860     40.046
# 2019-09                  906.956   39.045     32.647
# 2019-10                  980.948   45.213     39.065
# 2019-11                  872.046   42.237     36.180
# 2019-12                  692.232   39.732     28.749
#
# [12 rows x 27 columns]

# %%
df_previsto = pd.read_csv('previsto.csv')
df_previsto.set_index('Previsto (mil ton.)', inplace=True)
df_previsto = df_previsto.T
df_previsto
# Out:
# Previsto (mil ton.)       Acre    Alagoas      Amapá   Amazonas       Bahia  \
# 2019-01              10.588004  31.411154   9.501208  41.832558  241.000488
# 2019-02               9.887500  31.298338   8.632245  42.121399  234.734589
# 2019-03               9.137039  30.678967   7.668808  42.159924  241.413986
# 2019-04              11.065890  28.778185   7.218593  42.320068  238.897476
# 2019-05              14.703808  26.647188   8.082638  42.375652  249.633942
# 2019-06              15.797381  26.743784  11.798945  42.252373  271.788391
# 2019-07              15.578485  25.804504  12.630874  42.026302  274.342285
# 2019-08              14.840865  28.395733  12.714647  41.969299  291.001709
# 2019-09              15.269740  30.959930  12.755500  41.944267  297.122101
# 2019-10              15.295842  31.694130  12.859158  41.807213  295.220917
# 2019-11              12.644016  31.770985  12.721001  41.671284  276.489014
# 2019-12              11.066999  30.707354  11.775168  41.425652  253.551147
#
# Previsto (mil ton.)       Ceara  Distrito Federal  Espirito Santo      Goiais  \
# 2019-01              136.037567         41.502365       91.808304  173.949524
# 2019-02              133.645538         47.666981       91.718063  177.202637
# 2019-03              132.055634         44.906673       92.864807  178.273254
# 2019-04              132.553284         47.796688       93.605171  179.169922
# 2019-05              146.423218         46.763454       95.666306  206.121399
# 2019-06              154.595245         51.376087       98.896271  219.960266
# 2019-07              156.647095         56.722538      103.985153  213.096832
# 2019-08              158.369110         60.156025      107.212662  214.013351
# 2019-09              163.356964         59.981289      108.438232  217.520859
# 2019-10              177.059143         59.069294      108.153290  221.326126
# 2019-11              160.565048         58.039402      105.812271  221.463257
# 2019-12              137.189270         49.429443      102.787621  190.199463
#
# Previsto (mil ton.)   Maranhão  ...      Piauí  Rio Grande do Sul  \
# 2019-01              45.900345  ...  43.798309         224.073624
# 2019-02              48.293362  ...  39.821533         224.737152
# 2019-03              48.459515  ...  40.362175         224.386871
# 2019-04              54.826965  ...  41.983902         224.584915
# 2019-05              65.141991  ...  44.907383         225.509857
# 2019-06              71.251190  ...  48.281044         225.243393
# 2019-07              73.790543  ...  52.761776         224.136597
# 2019-08              75.246063  ...  56.840820         224.088882
# 2019-09              79.895622  ...  59.898911         223.791229
# 2019-10              81.740005  ...  61.170837         219.202255
# 2019-11              78.939095  ...  61.444008         219.673065
# 2019-12              70.624352  ...  61.086090         218.001266
#
# Previsto (mil ton.)  Rio de Janeiro  Rio Grande do Norte   Rondônia   Roraima  \
# 2019-01                  198.456207            39.395752  34.765495  8.532695
# 2019-02                  196.572144            38.957458  33.387203  8.647708
# 2019-03                  220.466171            38.448929  32.986847  8.748202
# 2019-04                  212.642761            37.901360  33.388702  8.868678
# 2019-05                  219.088531            37.384979  34.673424  8.996480
# 2019-06                  227.182327            37.964466  35.545189  9.122819
# 2019-07                  233.497742            40.373112  35.826767  9.211939
# 2019-08                  227.418427            46.662437  35.529655  9.327834
# 2019-09                  231.667908            51.325554  35.329575  9.416952
# 2019-10                  229.949371            52.167175  35.050934  9.455299
# 2019-11                  230.413849            48.787346  34.888557  9.446061
# 2019-12                  221.301392            43.793201  35.052608  9.373635
#
# Previsto (mil ton.)  Santa Catarina   São Paulo    Sergipe  Tocantins
# 2019-01                  218.556351  889.707031  30.166079  35.197155
# 2019-02                  220.791214  889.707031  30.189758  34.983727
# 2019-03                  214.038925  889.707031  29.858086  36.276012
# 2019-04                  230.178711  889.707031  29.598694  38.073910
# 2019-05                  240.807724  889.707031  29.650742  39.894753
# 2019-06                  252.747253  889.707031  29.957417  41.898125
# 2019-07                  275.880249  889.707031  30.204376  43.362984
# 2019-08                  272.183899  889.707031  31.196730  44.317303
# 2019-09                  254.709976  889.707031  32.828423  44.807762
# 2019-10                  251.131943  889.707031  34.296734  44.400082
# 2019-11                  249.035934  889.707153  35.415627  43.067780
# 2019-12                  241.285049  889.707031  35.478138  40.536385
#
# [12 rows x 27 columns]

# %%
def plot_time_series(df_registered, df_previsto):
    states = df_registered.columns  

    for state in states:
        plt.figure(figsize=(10, 2))
        plt.plot(df_registered.index, df_registered[state], 
                 label='Registrado', marker='o', color='#999999') 
        plt.plot(df_previsto.index, df_previsto[state], 
                 label='Previsto', marker='s', linestyle='dotted', color='#60A0EE') 

        actual = df_registered[state]
        predicted = df_previsto[state]
        mape = (100 / len(actual)) * sum(abs((actual - predicted) / actual))
        info_text = f'MAPE: {mape:.2f}%' 

        plt.text(1.01, 0.5, info_text, transform=plt.gca().transAxes, 
                 fontsize=10, verticalalignment='center')

        plt.xlabel('Mês')
        plt.ylabel('Mil Toneladas Cimento')
        plt.title(f'Previsão para {state}')
        plt.legend()
        plt.grid(True)
        plt.show()


plot_time_series(df_registered, df_previsto)
