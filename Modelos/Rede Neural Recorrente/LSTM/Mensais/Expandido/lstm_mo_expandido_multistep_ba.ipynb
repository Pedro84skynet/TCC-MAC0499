# %%
import tensorflow as tf
tf.__version__
tf.config.experimental.enable_op_determinism()
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
def plot_columns(df):
    colors = plt.cm.tab20(range(df.shape[1]))  

    for i, column in enumerate(df.columns):
        color = colors[i % 24]

        plt.figure()
        plt.plot(df.index, df[column], color=color)
        plt.xlabel('Tempo')
        plt.ylabel('Valor')
        plt.title(column)

    plt.show()

# %%
def plot_correlation_matrix(df):
    correlation_matrix = df.corr()
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title("Correlation Matrix Heatmap")
    plt.show()

# %%
tf.keras.backend.clear_session()

# %%
subject = 'Bahia - Consumo de Cimento (t)'
start_index = 0
split_index = 191 #Referente aos 230 anos de input 
window_size = 36
train_split = split_index + 1 - 30

# %%
data = pd.read_csv('2003_mo_model_input_BA.csv')
pd.set_option('display.max_columns', None)
data
# Out:
#     Unnamed: 0  Bahia - value  Bahia- custo m2 (R$)  \
# 0       2003-1       0.299858          10915.348400
# 1       2003-2       0.301903          11028.218400
# 2       2003-3       0.303709          11133.335807
# 3       2003-4       0.305311          11215.137236
# 4       2003-5       0.306860          11294.955512
# ..         ...            ...                   ...
# 268     2002-8            NaN                   NaN
# 269     2002-9            NaN                   NaN
# 270    2002-10            NaN                   NaN
# 271    2002-11            NaN                   NaN
# 272    2002-12            NaN                   NaN
#
#      Bahia - Consumo de Cimento (t)  Precipitation (mm/day)  \
# 0                           151.297                1.604227
# 1                           138.707                2.224533
# 2                           135.009                2.312330
# 3                           126.554                2.332765
# 4                           137.331                2.225842
# ..                              ...                     ...
# 268                             NaN                1.608320
# 269                             NaN                1.453784
# 270                             NaN                1.071670
# 271                             NaN                1.149319
# 272                             NaN                1.302823
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 0                 1007.701639                          1669.734463
# 1                 1007.849476                          1568.727444
# 2                 1008.259608                          1452.272884
# 3                 1009.143887                          1359.230366
# 4                 1010.005569                          1291.737281
# ..                        ...                                  ...
# 268               1010.371607                          1488.966218
# 269               1009.628033                          1569.704039
# 270               1008.927909                          1667.519304
# 271               1008.388051                          1694.210509
# 272               1007.896538                          1700.542177
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 0                          26.973700                   22.147525
# 1                          26.728784                   22.241910
# 2                          26.305364                   22.159668
# 3                          25.788306                   21.728601
# 4                          25.189925                   21.303605
# ..                               ...                         ...
# 268                        24.817842                   20.666681
# 269                        25.399925                   20.932220
# 270                        26.035253                   21.204426
# 271                        26.573861                   21.523948
# 272                        26.944260                   21.882852
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Bahia - IDH Educacao  \
# 0                    75.411587         2.004234              0.598394
# 1                    76.966756         1.726139              0.598795
# 2                    78.493126         1.462602              0.599196
# 3                    78.801800         1.217048              0.599597
# 4                    79.547467         1.031926              0.599998
# ..                         ...              ...                   ...
# 268                  78.229336         1.977754                   NaN
# 269                  76.934612         2.093929                   NaN
# 270                  75.331548         2.191347                   NaN
# 271                  74.405966         2.307342                   NaN
# 272                  74.400960         2.234476                   NaN
#
#      Bahia - IDH Longevidade  Bahia - IDH  Bahia - Produção de Cimento (t)  \
# 0                   0.766362     0.669899                        39.798880
# 1                   0.766745     0.670210                        39.480034
# 2                   0.767127     0.670521                        39.400256
# 3                   0.767509     0.670831                        39.417185
# 4                   0.767892     0.671142                        39.479943
# ..                       ...          ...                              ...
# 268                      NaN          NaN                              NaN
# 269                      NaN          NaN                              NaN
# 270                      NaN          NaN                              NaN
# 271                      NaN          NaN                              NaN
# 272                      NaN          NaN                              NaN
#
#      Bahia - Depósito Poupança (R$)  Bahia - IDH Renda  \
# 0                      7.782609e+06           0.638715
# 1                      7.827094e+06           0.638948
# 2                      7.871579e+06           0.639181
# 3                      7.916064e+06           0.639414
# 4                      7.960549e+06           0.639647
# ..                              ...                ...
# 268                             NaN                NaN
# 269                             NaN                NaN
# 270                             NaN                NaN
# 271                             NaN                NaN
# 272                             NaN                NaN
#
#      Bahia - PIB - Estadual  Bahia - PIB - Construção Civil  \
# 0              1.317344e+08                    8.384593e+06
# 1              1.318964e+08                    8.391946e+06
# 2              1.320584e+08                    8.399299e+06
# 3              1.322204e+08                    8.406652e+06
# 4              1.323824e+08                    8.414005e+06
# ..                      ...                             ...
# 268                     NaN                             NaN
# 269                     NaN                             NaN
# 270                     NaN                             NaN
# 271                     NaN                             NaN
# 272                     NaN                             NaN
#
#      Bahia - PIB - Per Capita  Bahia - PIB - Preços de Mercado  \
# 0                    8.566149                     1.216359e+08
# 1                    8.569210                     1.216914e+08
# 2                    8.572270                     1.217469e+08
# 3                    8.575331                     1.218023e+08
# 4                    8.578392                     1.218578e+08
# ..                        ...                              ...
# 268                       NaN                              NaN
# 269                       NaN                              NaN
# 270                       NaN                              NaN
# 271                       NaN                              NaN
# 272                       NaN                              NaN
#
#      Bahia - Desemprego  \
# 0              8.348779
# 1              8.342979
# 2              8.337179
# 3              8.331379
# 4              8.325579
# ..                  ...
# 268                 NaN
# 269                 NaN
# 270                 NaN
# 271                 NaN
# 272                 NaN
#
#      Operações de crédito - saldo da carteira de crédito (R$)  \
# 0                                        384683.093871
# 1                                        385266.203928
# 2                                        385305.059560
# 3                                        385752.052697
# 4                                        387164.022451
# ..                                                 ...
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
#
#      Estoque liquido de capital fixo - (R$)  EMBI + Risco-Brasil  \
# 0                              7.330309e+06           231.510748
# 1                              7.335910e+06           208.710157
# 2                              7.341511e+06           227.704841
# 3                              7.347112e+06           278.121073
# 4                              7.352713e+06           344.827633
# ..                                      ...                  ...
# 268                                     NaN                  NaN
# 269                                     NaN                  NaN
# 270                                     NaN                  NaN
# 271                                     NaN                  NaN
# 272                                     NaN                  NaN
#
#      Fundo de garantia por tempo de serviço (FGTS) (R$)    IGP-DI  \
# 0                                         2.097001e+06   1.036534
# 1                                         2.000523e+06   0.993449
# 2                                         1.963278e+06   0.973020
# 3                                         1.954187e+06   0.940489
# 4                                         1.975493e+06   0.917493
# ..                                                 ...        ...
# 268                                                NaN        NaN
# 269                                                NaN        NaN
# 270                                                NaN        NaN
# 271                                                NaN        NaN
# 272                                                NaN        NaN
#
#      Inadimplência da carteira de crédito  - total - (%)   INCC (%)  \
# 0                                             3.656420     0.969649
# 1                                             3.654697     0.950783
# 2                                             3.654266     0.938332
# 3                                             3.653595     0.926401
# 4                                             3.650266     0.951683
# ..                                                 ...          ...
# 268                                                NaN          NaN
# 269                                                NaN          NaN
# 270                                                NaN          NaN
# 271                                                NaN          NaN
# 272                                                NaN          NaN
#
#       IPCA - Variação mensal durante o Plano Real (%)  \
# 0                                            0.724032
# 1                                            0.690297
# 2                                            0.669681
# 3                                            0.660494
# 4                                            0.648337
# ..                                                ...
# 268                                               NaN
# 269                                               NaN
# 270                                               NaN
# 271                                               NaN
# 272                                               NaN
#
#       NFSP - Fluxo Mensal (Milhões de reais)  NFSP - Porcentagem do PIB (%)  \
# 0                               -5331.049150                      11.520143
# 1                               -5318.079644                      11.189862
# 2                               -5436.417870                      10.820792
# 3                               -5707.015274                      10.417840
# 4                               -5599.317941                       9.959690
# ..                                       ...                            ...
# 268                                      NaN                            NaN
# 269                                      NaN                            NaN
# 270                                      NaN                            NaN
# 271                                      NaN                            NaN
# 272                                      NaN                            NaN
#
#      PIB - Atividades imobiliárias (média 1995 = 100)     População  \
# 0                                          126.459809  1.772069e+08
# 1                                          126.581813  1.773884e+08
# 2                                          126.703818  1.775699e+08
# 3                                          126.825822  1.777514e+08
# 4                                          126.976217  1.779329e+08
# ..                                                ...           ...
# 268                                               NaN           NaN
# 269                                               NaN           NaN
# 270                                               NaN           NaN
# 271                                               NaN           NaN
# 272                                               NaN           NaN
#
#       PPC (US$)  Taxa Selic (%)
# 0    169.247665        1.611498
# 1    170.176810        1.450389
# 2    171.135713        1.870184
# 3    172.116904        1.355287
# 4    173.072271        1.585538
# ..          ...             ...
# 268         NaN             NaN
# 269         NaN             NaN
# 270         NaN             NaN
# 271         NaN             NaN
# 272         NaN             NaN
#
# [273 rows x 36 columns]

# %%
def calculate_monthly_means(consume_of_cement, subject):
    df = pd.DataFrame({subject: consume_of_cement[:train_split]})
    df['sazonalidade'] = df.index % 12
    monthly_means = df.groupby('sazonalidade')[subject].mean()
    result_df = pd.DataFrame({'sazonalidade': monthly_means})

    return result_df

media_df = calculate_monthly_means(data[subject], subject)
plot_columns(media_df)
media_df
# Out:
#               sazonalidade
# sazonalidade
# 0               240.981090
# 1               215.539900
# 2               245.202066
# 3               227.688361
# 4               245.118647
# 5               224.488539
# 6               242.991489
# 7               259.883879
# 8               257.939056
# 9               263.442771
# 10              247.868567
# 11              242.876615

# %%
def fill_original_df_with_monthly_means(df_og, media_df):
    monthly_means = media_df['sazonalidade'].tolist()
    df_og['sazonalidade'] = [monthly_means[i % 12] for i in range(len(df_og))]
    return df_og

data = fill_original_df_with_monthly_means(data, media_df)
data = data[[col for col in data.columns if col != subject] + [subject]] #Seta consumo (target) para a coluna final
data
# Out:
#     Unnamed: 0  Bahia - value  Bahia- custo m2 (R$)  Precipitation (mm/day)  \
# 0       2003-1       0.299858          10915.348400                1.604227
# 1       2003-2       0.301903          11028.218400                2.224533
# 2       2003-3       0.303709          11133.335807                2.312330
# 3       2003-4       0.305311          11215.137236                2.332765
# 4       2003-5       0.306860          11294.955512                2.225842
# ..         ...            ...                   ...                     ...
# 268     2002-8            NaN                   NaN                1.608320
# 269     2002-9            NaN                   NaN                1.453784
# 270    2002-10            NaN                   NaN                1.071670
# 271    2002-11            NaN                   NaN                1.149319
# 272    2002-12            NaN                   NaN                1.302823
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 0                 1007.701639                          1669.734463
# 1                 1007.849476                          1568.727444
# 2                 1008.259608                          1452.272884
# 3                 1009.143887                          1359.230366
# 4                 1010.005569                          1291.737281
# ..                        ...                                  ...
# 268               1010.371607                          1488.966218
# 269               1009.628033                          1569.704039
# 270               1008.927909                          1667.519304
# 271               1008.388051                          1694.210509
# 272               1007.896538                          1700.542177
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 0                          26.973700                   22.147525
# 1                          26.728784                   22.241910
# 2                          26.305364                   22.159668
# 3                          25.788306                   21.728601
# 4                          25.189925                   21.303605
# ..                               ...                         ...
# 268                        24.817842                   20.666681
# 269                        25.399925                   20.932220
# 270                        26.035253                   21.204426
# 271                        26.573861                   21.523948
# 272                        26.944260                   21.882852
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Bahia - IDH Educacao  \
# 0                    75.411587         2.004234              0.598394
# 1                    76.966756         1.726139              0.598795
# 2                    78.493126         1.462602              0.599196
# 3                    78.801800         1.217048              0.599597
# 4                    79.547467         1.031926              0.599998
# ..                         ...              ...                   ...
# 268                  78.229336         1.977754                   NaN
# 269                  76.934612         2.093929                   NaN
# 270                  75.331548         2.191347                   NaN
# 271                  74.405966         2.307342                   NaN
# 272                  74.400960         2.234476                   NaN
#
#      Bahia - IDH Longevidade  Bahia - IDH  Bahia - Produção de Cimento (t)  \
# 0                   0.766362     0.669899                        39.798880
# 1                   0.766745     0.670210                        39.480034
# 2                   0.767127     0.670521                        39.400256
# 3                   0.767509     0.670831                        39.417185
# 4                   0.767892     0.671142                        39.479943
# ..                       ...          ...                              ...
# 268                      NaN          NaN                              NaN
# 269                      NaN          NaN                              NaN
# 270                      NaN          NaN                              NaN
# 271                      NaN          NaN                              NaN
# 272                      NaN          NaN                              NaN
#
#      Bahia - Depósito Poupança (R$)  Bahia - IDH Renda  \
# 0                      7.782609e+06           0.638715
# 1                      7.827094e+06           0.638948
# 2                      7.871579e+06           0.639181
# 3                      7.916064e+06           0.639414
# 4                      7.960549e+06           0.639647
# ..                              ...                ...
# 268                             NaN                NaN
# 269                             NaN                NaN
# 270                             NaN                NaN
# 271                             NaN                NaN
# 272                             NaN                NaN
#
#      Bahia - PIB - Estadual  Bahia - PIB - Construção Civil  \
# 0              1.317344e+08                    8.384593e+06
# 1              1.318964e+08                    8.391946e+06
# 2              1.320584e+08                    8.399299e+06
# 3              1.322204e+08                    8.406652e+06
# 4              1.323824e+08                    8.414005e+06
# ..                      ...                             ...
# 268                     NaN                             NaN
# 269                     NaN                             NaN
# 270                     NaN                             NaN
# 271                     NaN                             NaN
# 272                     NaN                             NaN
#
#      Bahia - PIB - Per Capita  Bahia - PIB - Preços de Mercado  \
# 0                    8.566149                     1.216359e+08
# 1                    8.569210                     1.216914e+08
# 2                    8.572270                     1.217469e+08
# 3                    8.575331                     1.218023e+08
# 4                    8.578392                     1.218578e+08
# ..                        ...                              ...
# 268                       NaN                              NaN
# 269                       NaN                              NaN
# 270                       NaN                              NaN
# 271                       NaN                              NaN
# 272                       NaN                              NaN
#
#      Bahia - Desemprego  \
# 0              8.348779
# 1              8.342979
# 2              8.337179
# 3              8.331379
# 4              8.325579
# ..                  ...
# 268                 NaN
# 269                 NaN
# 270                 NaN
# 271                 NaN
# 272                 NaN
#
#      Operações de crédito - saldo da carteira de crédito (R$)  \
# 0                                        384683.093871
# 1                                        385266.203928
# 2                                        385305.059560
# 3                                        385752.052697
# 4                                        387164.022451
# ..                                                 ...
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
#
#      Estoque liquido de capital fixo - (R$)  EMBI + Risco-Brasil  \
# 0                              7.330309e+06           231.510748
# 1                              7.335910e+06           208.710157
# 2                              7.341511e+06           227.704841
# 3                              7.347112e+06           278.121073
# 4                              7.352713e+06           344.827633
# ..                                      ...                  ...
# 268                                     NaN                  NaN
# 269                                     NaN                  NaN
# 270                                     NaN                  NaN
# 271                                     NaN                  NaN
# 272                                     NaN                  NaN
#
#      Fundo de garantia por tempo de serviço (FGTS) (R$)    IGP-DI  \
# 0                                         2.097001e+06   1.036534
# 1                                         2.000523e+06   0.993449
# 2                                         1.963278e+06   0.973020
# 3                                         1.954187e+06   0.940489
# 4                                         1.975493e+06   0.917493
# ..                                                 ...        ...
# 268                                                NaN        NaN
# 269                                                NaN        NaN
# 270                                                NaN        NaN
# 271                                                NaN        NaN
# 272                                                NaN        NaN
#
#      Inadimplência da carteira de crédito  - total - (%)   INCC (%)  \
# 0                                             3.656420     0.969649
# 1                                             3.654697     0.950783
# 2                                             3.654266     0.938332
# 3                                             3.653595     0.926401
# 4                                             3.650266     0.951683
# ..                                                 ...          ...
# 268                                                NaN          NaN
# 269                                                NaN          NaN
# 270                                                NaN          NaN
# 271                                                NaN          NaN
# 272                                                NaN          NaN
#
#       IPCA - Variação mensal durante o Plano Real (%)  \
# 0                                            0.724032
# 1                                            0.690297
# 2                                            0.669681
# 3                                            0.660494
# 4                                            0.648337
# ..                                                ...
# 268                                               NaN
# 269                                               NaN
# 270                                               NaN
# 271                                               NaN
# 272                                               NaN
#
#       NFSP - Fluxo Mensal (Milhões de reais)  NFSP - Porcentagem do PIB (%)  \
# 0                               -5331.049150                      11.520143
# 1                               -5318.079644                      11.189862
# 2                               -5436.417870                      10.820792
# 3                               -5707.015274                      10.417840
# 4                               -5599.317941                       9.959690
# ..                                       ...                            ...
# 268                                      NaN                            NaN
# 269                                      NaN                            NaN
# 270                                      NaN                            NaN
# 271                                      NaN                            NaN
# 272                                      NaN                            NaN
#
#      PIB - Atividades imobiliárias (média 1995 = 100)     População  \
# 0                                          126.459809  1.772069e+08
# 1                                          126.581813  1.773884e+08
# 2                                          126.703818  1.775699e+08
# 3                                          126.825822  1.777514e+08
# 4                                          126.976217  1.779329e+08
# ..                                                ...           ...
# 268                                               NaN           NaN
# 269                                               NaN           NaN
# 270                                               NaN           NaN
# 271                                               NaN           NaN
# 272                                               NaN           NaN
#
#       PPC (US$)  Taxa Selic (%)  sazonalidade  Bahia - Consumo de Cimento (t)
# 0    169.247665        1.611498    240.981090                         151.297
# 1    170.176810        1.450389    215.539900                         138.707
# 2    171.135713        1.870184    245.202066                         135.009
# 3    172.116904        1.355287    227.688361                         126.554
# 4    173.072271        1.585538    245.118647                         137.331
# ..          ...             ...           ...                             ...
# 268         NaN             NaN    245.118647                             NaN
# 269         NaN             NaN    224.488539                             NaN
# 270         NaN             NaN    242.991489                             NaN
# 271         NaN             NaN    259.883879                             NaN
# 272         NaN             NaN    257.939056                             NaN
#
# [273 rows x 37 columns]

# %%
plot_data = data.iloc[:split_index + 1,1:]
plot_correlation_matrix(plot_data)

# %%
# data =data.drop(['Air Temperature - Dry Bulb (°C)',
#                  'Precipitation (mm/day)',
#                  'Global Radiation - Daylight (Kj/m²)', 
#                  'Air Relative Humidity (%)'], axis=1)
# data

# %%
input_data = data.iloc[:split_index + 1,1:-1]
mean = np.mean(input_data, axis=0)
stddev =  np.std(input_data, axis=0)
input_data = ((input_data - mean) /stddev)
# scaler=MinMaxScaler()
# scaled_data = scaler.fit_transform(input_data)
# input_data = pd.DataFrame(scaled_data, columns=input_data.columns)
input_data
# Out:
#      Bahia - value  Bahia- custo m2 (R$)  Precipitation (mm/day)  \
# 0        -1.440329             -1.671449               -0.038360
# 1        -1.404914             -1.644714                1.221742
# 2        -1.373637             -1.619815                1.400094
# 3        -1.345888             -1.600440                1.441606
# 4        -1.319065             -1.581534                1.224400
# ..             ...                   ...                     ...
# 187       1.796141              1.727528               -0.479209
# 188       1.811284              1.753086                0.014731
# 189       1.833479              1.782312                0.024464
# 190       1.853109              1.814876               -0.195334
# 191       1.880066              1.852332                0.690450
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 0                   -0.693716                             1.240513
# 1                   -0.603174                             0.710245
# 2                   -0.351990                             0.098880
# 3                    0.189583                            -0.389576
# 4                    0.717316                            -0.743902
# ..                        ...                                  ...
# 187                  0.697302                            -0.057929
# 188                  0.264175                             0.241939
# 189                  0.049785                             0.693616
# 190                 -0.223773                             1.086440
# 191                 -0.409591                             1.123925
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 0                           0.642079                    0.029035
# 1                           0.432351                    0.060353
# 2                           0.069766                    0.033064
# 3                          -0.373005                   -0.109968
# 4                          -0.885415                   -0.250986
# ..                               ...                         ...
# 187                        -0.798014                   -0.498914
# 188                        -0.526252                   -0.419733
# 189                        -0.151337                   -0.321149
# 190                         0.283656                   -0.205138
# 191                         0.611286                   -0.086784
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Bahia - IDH Educacao  \
# 0                    -0.182257         1.402525             -1.848551
# 1                     0.138191         0.499197             -1.825983
# 2                     0.452705        -0.356839             -1.803414
# 3                     0.516308        -1.154465             -1.780846
# 4                     0.669955        -1.755788             -1.758277
# ..                         ...              ...                   ...
# 187                  -0.113596        -0.437518              1.367030
# 188                  -0.176406        -0.385163              1.365214
# 189                  -0.283086        -0.415774              1.363397
# 190                  -0.406765        -0.475393              1.361580
# 191                  -0.408326        -0.589886              1.359763
#
#      Bahia - IDH Longevidade  Bahia - IDH  Bahia - Produção de Cimento (t)  \
# 0                  -2.549555    -2.143224                        -1.723080
# 1                  -2.497686    -2.108465                        -1.735985
# 2                  -2.445817    -2.073707                        -1.739214
# 3                  -2.393948    -2.038948                        -1.738529
# 4                  -2.342079    -2.004190                        -1.735989
# ..                       ...          ...                              ...
# 187                 0.984883     1.261516                         0.511535
# 188                 0.962848     1.253736                         0.513264
# 189                 0.940812     1.245956                         0.526782
# 190                 0.918777     1.238176                         0.525379
# 191                 0.896742     1.230396                         0.525808
#
#      Bahia - Depósito Poupança (R$)  Bahia - IDH Renda  \
# 0                         -1.584098          -2.149391
# 1                         -1.574477          -2.116918
# 2                         -1.564855          -2.084445
# 3                         -1.555234          -2.051972
# 4                         -1.545612          -2.019499
# ..                              ...                ...
# 187                        1.225571           1.109537
# 188                        1.232652           1.096596
# 189                        1.239733           1.083655
# 190                        1.246815           1.070714
# 191                        1.253896           1.057773
#
#      Bahia - PIB - Estadual  Bahia - PIB - Construção Civil  \
# 0                 -1.703176                       -0.816345
# 1                 -1.684201                       -0.772933
# 2                 -1.665225                       -0.729522
# 3                 -1.646249                       -0.686111
# 4                 -1.627274                       -0.642700
# ..                      ...                             ...
# 187                1.096947                       -1.668064
# 188                1.085441                       -1.663847
# 189                1.073935                       -1.659631
# 190                1.062429                       -1.655414
# 191                1.050923                       -1.651197
#
#      Bahia - PIB - Per Capita  Bahia - PIB - Preços de Mercado  \
# 0                   -2.235724                        -2.158201
# 1                   -2.194204                        -2.117854
# 2                   -2.152684                        -2.077508
# 3                   -2.111164                        -2.037161
# 4                   -2.069645                        -1.996814
# ..                        ...                              ...
# 187                  0.877256                         0.724962
# 188                  0.851021                         0.704849
# 189                  0.824786                         0.684737
# 190                  0.798552                         0.664624
# 191                  0.772317                         0.644511
#
#      Bahia - Desemprego  \
# 0             -0.884052
# 1             -0.885724
# 2             -0.887395
# 3             -0.889067
# 4             -0.890739
# ..                  ...
# 187            1.200853
# 188            1.200487
# 189            1.200122
# 190            1.199756
# 191            1.199390
#
#      Operações de crédito - saldo da carteira de crédito (R$)  \
# 0                                            -1.361787
# 1                                            -1.361224
# 2                                            -1.361187
# 3                                            -1.360756
# 4                                            -1.359394
# ..                                                 ...
# 187                                           1.316363
# 188                                           1.330590
# 189                                           1.352241
# 190                                           1.370978
# 191                                           1.385781
#
#      Estoque liquido de capital fixo - (R$)  EMBI + Risco-Brasil  \
# 0                                 -2.389042            -0.582420
# 1                                 -2.352139            -0.799075
# 2                                 -2.315236            -0.618584
# 3                                 -2.278333            -0.139520
# 4                                 -2.241431             0.494336
# ..                                      ...                  ...
# 187                                0.389193            -0.244459
# 188                                0.370392            -0.199028
# 189                                0.351592            -0.173807
# 190                                0.332791            -0.169867
# 191                                0.313991            -0.166458
#
#      Fundo de garantia por tempo de serviço (FGTS) (R$)    IGP-DI  \
# 0                                            -1.347324   3.890153
# 1                                            -1.380245   3.551840
# 2                                            -1.392954   3.391423
# 3                                            -1.396056   3.135979
# 4                                            -1.388786   2.955412
# ..                                                 ...        ...
# 187                                           1.237409   0.589021
# 188                                           1.214214   1.043728
# 189                                           1.409043   1.387010
# 190                                           1.654237   1.815728
# 191                                           1.791041   2.181106
#
#      Inadimplência da carteira de crédito  - total - (%)   INCC (%)  \
# 0                                             1.258423     3.122582
# 1                                             1.252755     2.970356
# 2                                             1.251338     2.869895
# 3                                             1.249134     2.773628
# 4                                             1.238186     2.977624
# ..                                                 ...          ...
# 187                                          -0.685819    -1.749976
# 188                                          -0.770458    -1.593005
# 189                                          -0.910077    -1.351489
# 190                                          -1.020687    -1.198492
# 191                                          -1.103613    -1.100894
#
#       IPCA - Variação mensal durante o Plano Real (%)  \
# 0                                            2.723741
# 1                                            2.350880
# 2                                            2.123016
# 3                                            2.021477
# 4                                            1.887113
# ..                                                ...
# 187                                         -2.010387
# 188                                         -1.870713
# 189                                         -1.806230
# 190                                         -1.727496
# 191                                         -1.391283
#
#       NFSP - Fluxo Mensal (Milhões de reais)  NFSP - Porcentagem do PIB (%)  \
# 0                                   0.364808                       4.398348
# 1                                   0.368956                       4.222509
# 2                                   0.331110                       4.026019
# 3                                   0.244570                       3.811492
# 4                                   0.279013                       3.567576
# ..                                       ...                            ...
# 187                                 2.953658                      -0.572934
# 188                                 3.351323                      -0.588777
# 189                                 3.404908                      -0.612606
# 190                                 3.671303                      -0.640956
# 191                                 4.051551                      -0.663358
#
#      PIB - Atividades imobiliárias (média 1995 = 100)  População  PPC (US$)  \
# 0                                           -1.873379  -2.042341  -1.825286
# 1                                           -1.868164  -2.014760  -1.813648
# 2                                           -1.862949  -1.987179  -1.801637
# 3                                           -1.857734  -1.959598  -1.789347
# 4                                           -1.851305  -1.932017  -1.777381
# ..                                                ...        ...        ...
# 187                                          1.406756   1.365911   1.413217
# 188                                          1.428132   1.376610   1.425045
# 189                                          1.449507   1.387308   1.436067
# 190                                          1.463901   1.398006   1.446142
# 191                                          1.478294   1.408704   1.454722
#
#      Taxa Selic (%)  sazonalidade
# 0          2.132459     -0.134088
# 1          1.592202     -1.974093
# 2          2.999926      0.171189
# 3          1.273293     -1.095469
# 4          2.045407      0.165156
# ..              ...           ...
# 187       -1.311366      1.233035
# 188       -1.417143      1.092378
# 189       -1.597784      1.490427
# 190       -1.400787      0.364041
# 191       -1.604775      0.003004
#
# [192 rows x 35 columns]

# %%
# Shift para prever futuro e não presente
target_data = data[subject].shift(-12)
target_data
# Out:
# 0      129.857
# 1      126.813
# 2      152.225
# 3      136.288
# 4      148.117
#         ...
# 268        NaN
# 269        NaN
# 270        NaN
# 271        NaN
# 272        NaN
# Name: Bahia - Consumo de Cimento (t), Length: 273, dtype: float64

# %%
# input para treinamento
train_input = input_data.iloc[start_index:train_split]
train_input
# Out:
#      Bahia - value  Bahia- custo m2 (R$)  Precipitation (mm/day)  \
# 0        -1.440329             -1.671449               -0.038360
# 1        -1.404914             -1.644714                1.221742
# 2        -1.373637             -1.619815                1.400094
# 3        -1.345888             -1.600440                1.441606
# 4        -1.319065             -1.581534                1.224400
# ..             ...                   ...                     ...
# 157       1.097864              1.097398               -0.463180
# 158       1.120412              1.117123               -0.366119
# 159       1.139591              1.137362               -0.415933
# 160       1.156903              1.154862               -0.184106
# 161       1.173599              1.173049               -0.603064
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 0                   -0.693716                             1.240513
# 1                   -0.603174                             0.710245
# 2                   -0.351990                             0.098880
# 3                    0.189583                            -0.389576
# 4                    0.717316                            -0.743902
# ..                        ...                                  ...
# 157                 -0.124526                             0.716001
# 158                  0.218896                             0.134174
# 159                  0.632077                            -0.347743
# 160                  1.099938                            -0.659225
# 161                  1.357710                            -0.595662
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 0                           0.642079                    0.029035
# 1                           0.432351                    0.060353
# 2                           0.069766                    0.033064
# 3                          -0.373005                   -0.109968
# 4                          -0.885415                   -0.250986
# ..                               ...                         ...
# 157                         0.740382                   -0.089711
# 158                         0.476543                   -0.138090
# 159                         0.001694                   -0.258235
# 160                        -0.480778                   -0.393645
# 161                        -0.724193                   -0.503283
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Bahia - IDH Educacao  \
# 0                    -0.182257         1.402525             -1.848551
# 1                     0.138191         0.499197             -1.825983
# 2                     0.452705        -0.356839             -1.803414
# 3                     0.516308        -1.154465             -1.780846
# 4                     0.669955        -1.755788             -1.758277
# ..                         ...              ...                   ...
# 157                  -0.552869        -0.500043              1.377660
# 158                  -0.420868        -0.369291              1.377535
# 159                  -0.273422        -0.389089              1.377409
# 160                  -0.149855        -0.325560              1.377283
# 161                  -0.213338        -0.290637              1.377157
#
#      Bahia - IDH Longevidade  Bahia - IDH  Bahia - Produção de Cimento (t)  \
# 0                  -2.549555    -2.143224                        -1.723080
# 1                  -2.497686    -2.108465                        -1.735985
# 2                  -2.445817    -2.073707                        -1.739214
# 3                  -2.393948    -2.038948                        -1.738529
# 4                  -2.342079    -2.004190                        -1.735989
# ..                       ...          ...                              ...
# 157                 1.460539     1.430739                         0.617097
# 158                 1.449245     1.428086                         0.590103
# 159                 1.437951     1.425433                         0.561454
# 160                 1.426657     1.422780                         0.523492
# 161                 1.415363     1.420127                         0.512378
#
#      Bahia - Depósito Poupança (R$)  Bahia - IDH Renda  \
# 0                         -1.584098          -2.149391
# 1                         -1.574477          -2.116918
# 2                         -1.564855          -2.084445
# 3                         -1.555234          -2.051972
# 4                         -1.545612          -2.019499
# ..                              ...                ...
# 157                        0.815243           1.280030
# 158                        0.827342           1.271980
# 159                        0.839442           1.263929
# 160                        0.851541           1.255878
# 161                        0.863641           1.247827
#
#      Bahia - PIB - Estadual  Bahia - PIB - Construção Civil  \
# 0                 -1.703176                       -0.816345
# 1                 -1.684201                       -0.772933
# 2                 -1.665225                       -0.729522
# 3                 -1.646249                       -0.686111
# 4                 -1.627274                       -0.642700
# ..                      ...                             ...
# 157                1.205171                       -1.332406
# 158                1.206522                       -1.357999
# 159                1.207873                       -1.383592
# 160                1.209225                       -1.409185
# 161                1.210576                       -1.434778
#
#      Bahia - PIB - Per Capita  Bahia - PIB - Preços de Mercado  \
# 0                   -2.235724                        -2.158201
# 1                   -2.194204                        -2.117854
# 2                   -2.152684                        -2.077508
# 3                   -2.111164                        -2.037161
# 4                   -2.069645                        -1.996814
# ..                        ...                              ...
# 157                  1.004714                         1.051323
# 158                  1.007770                         1.045502
# 159                  1.010826                         1.039682
# 160                  1.013881                         1.033862
# 161                  1.016937                         1.028042
#
#      Bahia - Desemprego  \
# 0             -0.884052
# 1             -0.885724
# 2             -0.887395
# 3             -0.889067
# 4             -0.890739
# ..                  ...
# 157            1.273469
# 158            1.268173
# 159            1.262877
# 160            1.257581
# 161            1.252286
#
#      Operações de crédito - saldo da carteira de crédito (R$)  \
# 0                                            -1.361787
# 1                                            -1.361224
# 2                                            -1.361187
# 3                                            -1.360756
# 4                                            -1.359394
# ..                                                 ...
# 157                                           1.335787
# 158                                           1.325546
# 159                                           1.315396
# 160                                           1.306664
# 161                                           1.296665
#
#      Estoque liquido de capital fixo - (R$)  EMBI + Risco-Brasil  \
# 0                                 -2.389042            -0.582420
# 1                                 -2.352139            -0.799075
# 2                                 -2.315236            -0.618584
# 3                                 -2.278333            -0.139520
# 4                                 -2.241431             0.494336
# ..                                      ...                  ...
# 157                                0.819304             0.961603
# 158                                0.808136             1.030624
# 159                                0.796969             1.039183
# 160                                0.785801             1.017171
# 161                                0.774634             0.956920
#
#      Fundo de garantia por tempo de serviço (FGTS) (R$)    IGP-DI  \
# 0                                            -1.347324   3.890153
# 1                                            -1.380245   3.551840
# 2                                            -1.392954   3.391423
# 3                                            -1.396056   3.135979
# 4                                            -1.388786   2.955412
# ..                                                 ...        ...
# 157                                           1.338424  -1.233012
# 158                                           1.300351  -1.299304
# 159                                           1.250508  -1.248662
# 160                                           1.240363  -1.068274
# 161                                           1.233270  -1.035336
#
#      Inadimplência da carteira de crédito  - total - (%)   INCC (%)  \
# 0                                             1.258423     3.122582
# 1                                             1.252755     2.970356
# 2                                             1.251338     2.869895
# 3                                             1.249134     2.773628
# 4                                             1.238186     2.977624
# ..                                                 ...          ...
# 157                                           0.749349    -0.883659
# 158                                           0.977327    -0.950771
# 159                                           1.048267    -1.028465
# 160                                           1.048868    -1.103668
# 161                                           1.003993    -0.978419
#
#       IPCA - Variação mensal durante o Plano Real (%)  \
# 0                                            2.723741
# 1                                            2.350880
# 2                                            2.123016
# 3                                            2.021477
# 4                                            1.887113
# ..                                                ...
# 157                                         -0.214006
# 158                                         -0.434717
# 159                                         -0.524091
# 160                                         -0.614500
# 161                                         -0.552198
#
#       NFSP - Fluxo Mensal (Milhões de reais)  NFSP - Porcentagem do PIB (%)  \
# 0                                   0.364808                       4.398348
# 1                                   0.368956                       4.222509
# 2                                   0.331110                       4.026019
# 3                                   0.244570                       3.811492
# 4                                   0.279013                       3.567576
# ..                                       ...                            ...
# 157                                 1.216560                      -0.607704
# 158                                 1.155373                      -0.620523
# 159                                 1.056140                      -0.631530
# 160                                 1.147619                      -0.640320
# 161                                 1.118091                      -0.649685
#
#      PIB - Atividades imobiliárias (média 1995 = 100)  População  PPC (US$)  \
# 0                                           -1.873379  -2.042341  -1.825286
# 1                                           -1.868164  -2.014760  -1.813648
# 2                                           -1.862949  -1.987179  -1.801637
# 3                                           -1.857734  -1.959598  -1.789347
# 4                                           -1.851305  -1.932017  -1.777381
# ..                                                ...        ...        ...
# 157                                          0.952667   1.031384   1.044043
# 158                                          0.954843   1.042716   1.056960
# 159                                          0.957019   1.054049   1.070172
# 160                                          0.956331   1.065381   1.083626
# 161                                          0.955643   1.076713   1.096383
#
#      Taxa Selic (%)  sazonalidade
# 0          2.132459     -0.134088
# 1          1.592202     -1.974093
# 2          2.999926      0.171189
# 3          1.273293     -1.095469
# 4          2.045407      0.165156
# ..              ...           ...
# 157        0.043807     -1.974093
# 158        0.210856      0.171189
# 159        0.107070     -1.095469
# 160        0.392942      0.165156
# 161        0.714458     -1.326893
#
# [162 rows x 35 columns]

# %%
# Alvo para treinamento
train_target = target_data.iloc[start_index:train_split]
train_target
# Out:
# 0      129.857
# 1      126.813
# 2      152.225
# 3      136.288
# 4      148.117
#         ...
# 157    213.266
# 158    285.938
# 159    219.576
# 160    267.203
# 161    240.714
# Name: Bahia - Consumo de Cimento (t), Length: 162, dtype: float64

# %%
def create_batches(t_input, t_target, window_size, start_from):
    
    X_batches = []
    y_batches = []

    train_input_values = t_input.values 

    for i in range(len(t_input) - window_size):
        
        X_window = train_input_values[i:i+window_size, :]
        y_target = t_target[start_from+i+window_size]

        X_batches.append(X_window)
        y_batches.append(y_target)

    return np.array(X_batches), np.array(y_batches)

# %%
reshaped_train, reshaped_target = create_batches(train_input, 
                                                 train_target, 
                                                 window_size, 
                                                 start_index)
reshaped_train.shape
# Out:
# (126, 36, 35)

# %%
# input para treinamento
test_input = input_data.iloc[train_split - window_size:split_index + 1]
test_input
# Out:
#      Bahia - value  Bahia- custo m2 (R$)  Precipitation (mm/day)  \
# 126       0.558660              0.467576                0.398433
# 127       0.586295              0.485932                0.881864
# 128       0.614441              0.504868                1.489586
# 129       0.639726              0.524071                1.573881
# 130       0.666428              0.542675                1.385770
# ..             ...                   ...                     ...
# 187       1.796141              1.727528               -0.479209
# 188       1.811284              1.753086                0.014731
# 189       1.833479              1.782312                0.024464
# 190       1.853109              1.814876               -0.195334
# 191       1.880066              1.852332                0.690450
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 126                  0.532679                            -0.668258
# 127                  0.430146                            -0.313819
# 128                  0.052429                            -0.053698
# 129                 -0.261929                             0.254958
# 130                 -0.590265                             0.532349
# ..                        ...                                  ...
# 187                  0.697302                            -0.057929
# 188                  0.264175                             0.241939
# 189                  0.049785                             0.693616
# 190                 -0.223773                             1.086440
# 191                 -0.409591                             1.123925
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 126                        -1.288408                   -0.301039
# 127                        -1.213327                   -0.305019
# 128                        -0.954125                   -0.212853
# 129                        -0.665839                   -0.129927
# 130                        -0.411419                   -0.036978
# ..                               ...                         ...
# 187                        -0.798014                   -0.498914
# 188                        -0.526252                   -0.419733
# 189                        -0.151337                   -0.321149
# 190                         0.283656                   -0.205138
# 191                         0.611286                   -0.086784
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Bahia - IDH Educacao  \
# 126                   0.974067        -0.100403              0.540328
# 127                   0.883592         0.125796              0.557903
# 128                   0.871901         0.231163              0.575478
# 129                   0.796449         0.231164              0.593053
# 130                   0.790608         0.097551              0.610629
# ..                         ...              ...                   ...
# 187                  -0.113596        -0.437518              1.367030
# 188                  -0.176406        -0.385163              1.365214
# 189                  -0.283086        -0.415774              1.363397
# 190                  -0.406765        -0.475393              1.361580
# 191                  -0.408326        -0.589886              1.359763
#
#      Bahia - IDH Longevidade  Bahia - IDH  Bahia - Produção de Cimento (t)  \
# 126                 0.348354     0.461215                         1.205505
# 127                 0.342681     0.471044                         1.203037
# 128                 0.337008     0.480874                         1.178322
# 129                 0.331335     0.490704                         1.155459
# 130                 0.325662     0.500533                         1.124580
# ..                       ...          ...                              ...
# 187                 0.984883     1.261516                         0.511535
# 188                 0.962848     1.253736                         0.513264
# 189                 0.940812     1.245956                         0.526782
# 190                 0.918777     1.238176                         0.525379
# 191                 0.896742     1.230396                         0.525808
#
#      Bahia - Depósito Poupança (R$)  Bahia - IDH Renda  \
# 126                        1.056196           0.727414
# 127                        1.078359           0.721238
# 128                        1.100522           0.715062
# 129                        1.122685           0.708886
# 130                        1.144848           0.702709
# ..                              ...                ...
# 187                        1.225571           1.109537
# 188                        1.232652           1.096596
# 189                        1.239733           1.083655
# 190                        1.246815           1.070714
# 191                        1.253896           1.057773
#
#      Bahia - PIB - Estadual  Bahia - PIB - Construção Civil  \
# 126                0.833268                        0.194482
# 127                0.852943                        0.147537
# 128                0.872618                        0.100591
# 129                0.892293                        0.053646
# 130                0.911968                        0.006700
# ..                      ...                             ...
# 187                1.096947                       -1.668064
# 188                1.085441                       -1.663847
# 189                1.073935                       -1.659631
# 190                1.062429                       -1.655414
# 191                1.050923                       -1.651197
#
#      Bahia - PIB - Per Capita  Bahia - PIB - Preços de Mercado  \
# 126                  0.840990                         1.014636
# 127                  0.856945                         1.027926
# 128                  0.872900                         1.041216
# 129                  0.888855                         1.054506
# 130                  0.904809                         1.067796
# ..                        ...                              ...
# 187                  0.877256                         0.724962
# 188                  0.851021                         0.704849
# 189                  0.824786                         0.684737
# 190                  0.798552                         0.664624
# 191                  0.772317                         0.644511
#
#      Bahia - Desemprego  \
# 126            0.957509
# 127            0.975019
# 128            0.992528
# 129            1.010038
# 130            1.027547
# ..                  ...
# 187            1.200853
# 188            1.200487
# 189            1.200122
# 190            1.199756
# 191            1.199390
#
#      Operações de crédito - saldo da carteira de crédito (R$)  \
# 126                                           0.722924
# 127                                           0.745258
# 128                                           0.767990
# 129                                           0.799035
# 130                                           0.830824
# ..                                                 ...
# 187                                           1.316363
# 188                                           1.330590
# 189                                           1.352241
# 190                                           1.370978
# 191                                           1.385781
#
#      Estoque liquido de capital fixo - (R$)  EMBI + Risco-Brasil  \
# 126                                0.944085            -0.882533
# 127                                0.947319            -0.815413
# 128                                0.950553            -0.745839
# 129                                0.953786            -0.687348
# 130                                0.957020            -0.639220
# ..                                      ...                  ...
# 187                                0.389193            -0.244459
# 188                                0.370392            -0.199028
# 189                                0.351592            -0.173807
# 190                                0.332791            -0.169867
# 191                                0.313991            -0.166458
#
#      Fundo de garantia por tempo de serviço (FGTS) (R$)    IGP-DI  \
# 126                                           0.551812  -0.368821
# 127                                           0.566622  -0.328087
# 128                                           0.568617  -0.176031
# 129                                           0.719776  -0.113037
# 130                                           0.905478  -0.022703
# ..                                                 ...        ...
# 187                                           1.237409   0.589021
# 188                                           1.214214   1.043728
# 189                                           1.409043   1.387010
# 190                                           1.654237   1.815728
# 191                                           1.791041   2.181106
#
#      Inadimplência da carteira de crédito  - total - (%)   INCC (%)  \
# 126                                          -0.155884     0.045243
# 127                                          -0.349984     0.061828
# 128                                          -0.529294     0.046225
# 129                                          -0.788101     0.032522
# 130                                          -1.020394     0.042757
# ..                                                 ...          ...
# 187                                          -0.685819    -1.749976
# 188                                          -0.770458    -1.593005
# 189                                          -0.910077    -1.351489
# 190                                          -1.020687    -1.198492
# 191                                          -1.103613    -1.100894
#
#       IPCA - Variação mensal durante o Plano Real (%)  \
# 126                                          0.888984
# 127                                          0.954254
# 128                                          1.045217
# 129                                          1.176395
# 130                                          1.303259
# ..                                                ...
# 187                                         -2.010387
# 188                                         -1.870713
# 189                                         -1.806230
# 190                                         -1.727496
# 191                                         -1.391283
#
#       NFSP - Fluxo Mensal (Milhões de reais)  NFSP - Porcentagem do PIB (%)  \
# 126                                -0.230612                      -0.460555
# 127                                -0.156322                      -0.440372
# 128                                -0.120008                      -0.419247
# 129                                -0.143194                      -0.397019
# 130                                -0.028712                      -0.376532
# ..                                       ...                            ...
# 187                                 2.953658                      -0.572934
# 188                                 3.351323                      -0.588777
# 189                                 3.404908                      -0.612606
# 190                                 3.671303                      -0.640956
# 191                                 4.051551                      -0.663358
#
#      PIB - Atividades imobiliárias (média 1995 = 100)  População  PPC (US$)  \
# 126                                          0.913820   0.651397   0.697312
# 127                                          0.923198   0.664707   0.706933
# 128                                          0.932576   0.678017   0.715675
# 129                                          0.941953   0.691327   0.723490
# 130                                          0.942711   0.704637   0.730579
# ..                                                ...        ...        ...
# 187                                          1.406756   1.365911   1.413217
# 188                                          1.428132   1.376610   1.425045
# 189                                          1.449507   1.387308   1.436067
# 190                                          1.463901   1.398006   1.446142
# 191                                          1.478294   1.408704   1.454722
#
#      Taxa Selic (%)  sazonalidade
# 126       -1.048761      0.011312
# 127       -0.649312      1.233035
# 128       -0.535369      1.092378
# 129       -1.288807      1.490427
# 130       -1.507550      0.364041
# ..              ...           ...
# 187       -1.311366      1.233035
# 188       -1.417143      1.092378
# 189       -1.597784      1.490427
# 190       -1.400787      0.364041
# 191       -1.604775      0.003004
#
# [66 rows x 35 columns]

# %%
reshaped_test, reshaped_test_target = create_batches(test_input, 
                                                     target_data, 
                                                     window_size, 
                                                     train_split - window_size)
reshaped_test.shape
# Out:
# (30, 36, 35)

# %%
def validation_splitter(arr, div_factor, add_factor=0):
    split_factor = len(arr) // div_factor
    positions_to_drop_index = []
    positions_to_drop = []
    for i in range(split_factor):
        pos = len(arr) - (i * div_factor + 1)
        positions_to_drop_index.append(pos)
        positions_to_drop.append(pos + add_factor)
    
    arr_droped = arr[positions_to_drop]
    arr_result = np.delete(arr, positions_to_drop_index, axis=0)
    
    return arr_result, arr_droped

# %%
# Rede Neural Recorrente com optmizador Estocástico
def lstm_model(train_input, train_target, want_verbose=1, seed=0):
    if seed != 0:
        random.seed(seed)
        np.random.seed(seed)
        tf.random.set_seed(seed)
    # Aṕos 500 epochs sem grandes melhoras no val_loss, interrompe.
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', 
                                                      patience=100, 
                                                      verbose=want_verbose, 
                                                      restore_best_weights=True,
                                                      start_from_epoch=20)
#     train, train_val = validation_splitter(train_input, 7)
#     target,target_val = validation_splitter(train_target, 7)
#     display(train.shape)
#     display(train_val.shape)
#     display(target.shape)
#     display(target_val.shape)
    # Método estocástico e learning rate=0.005
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.005)
    model = tf.keras.Sequential([
        tf.keras.layers.LSTM(128, activation='tanh', return_sequences=True, 
                                      input_shape=(train_input.shape[1], train_input.shape[2])),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.LSTM(64, activation='tanh'),
        tf.keras.layers.Dense(1)
    ])
    model.compile(optimizer=optimizer, loss='mean_squared_error')   
    history = model.fit(train_input, 
                        train_target, 
                        epochs=200,
#                         validation_data=(train_val,
#                                          target_val),
                        validation_split=0.1,
                        callbacks=[early_stopping], 
                        verbose=want_verbose)
    return model, history

# %%
def get_a_good_seed(train_input, train_target, test_input, test_target):

    random_seeds = [random.randint(0, 2**32 - 1) for _ in range(10)]
    print(random_seeds)

    best_loss = float('inf')
    winner_seed = None
    i = 0
    for seed in random_seeds:
        print(f"\n\nStep: {i} ___________________________________________")
        i += 1

        model, history = lstm_model(train_input, train_target, want_verbose=0, seed=seed)
        current_loss = min(history.history['val_loss'][20:])
        print(f"val_loss: {current_loss}")

        if current_loss < best_loss:
            best_loss = current_loss
            winner_seed = seed
            print(f"winner_seed: {winner_seed}")
            if winner_seed == 0.0:
                return winner_seed

    return winner_seed

# %%
winner_seed = get_a_good_seed(reshaped_train, reshaped_target, reshaped_test, reshaped_test_target)
print(f"\n\nfinal_seed: {winner_seed}")
# Out:
# [3276593520, 853984725, 245707845, 210665373, 682795746, 1628895984, 3689525599, 2933523788, 253862587, 1346981268]
#
#
# Step: 0 ___________________________________________
# 2023-10-22 11:33:47.099271: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-22 11:33:47.099462: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-22 11:33:47.099604: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-22 11:33:47.167614: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-22 11:33:47.167788: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-22 11:33:47.167947: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-22 11:33:47.168107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10027 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:08:00.0, compute capability: 8.6
# 2023-10-22 11:33:48.878529: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8904
# 2023-10-22 11:33:48.954409: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-10-22 11:33:48.959919: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x428cef0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-22 11:33:48.959936: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2023-10-22 11:33:49.015698: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# val_loss: 537.95947265625
# winner_seed: 3276593520
#
#
# Step: 1 ___________________________________________
# val_loss: 404.5072021484375
# winner_seed: 853984725
#
#
# Step: 2 ___________________________________________
# val_loss: 520.802978515625
#
#
# Step: 3 ___________________________________________
# val_loss: 629.6521606445312
#
#
# Step: 4 ___________________________________________
# val_loss: 394.9695129394531
# winner_seed: 682795746
#
#
# Step: 5 ___________________________________________
# val_loss: 422.84429931640625
#
#
# Step: 6 ___________________________________________
# val_loss: 272.66943359375
# winner_seed: 3689525599
#
#
# Step: 7 ___________________________________________
# val_loss: 365.6938781738281
#
#
# Step: 8 ___________________________________________
# val_loss: 536.9913330078125
#
#
# Step: 9 ___________________________________________
# val_loss: 462.9783020019531
#
#
# final_seed: 3689525599

# %%
trained_model, history = lstm_model(reshaped_train, 
                                    reshaped_target, 
                                    want_verbose=1, 
                                    seed=winner_seed)
# 2536234443
# Out:
# Epoch 1/200
# 4/4 [==============================] - 2s 111ms/step - loss: 71698.5547 - val_loss: 47652.8203
# Epoch 2/200
# 4/4 [==============================] - 0s 8ms/step - loss: 11314.9082 - val_loss: 1081.8778
# Epoch 3/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2007.1820 - val_loss: 1780.9735
# Epoch 4/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1459.7572 - val_loss: 2443.6289
# Epoch 5/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1154.1201 - val_loss: 1696.5416
# Epoch 6/200
# 4/4 [==============================] - 0s 8ms/step - loss: 967.8608 - val_loss: 2604.6174
# Epoch 7/200
# 4/4 [==============================] - 0s 7ms/step - loss: 926.4102 - val_loss: 2137.2988
# Epoch 8/200
# 4/4 [==============================] - 0s 8ms/step - loss: 922.2958 - val_loss: 891.3978
# Epoch 9/200
# 4/4 [==============================] - 0s 8ms/step - loss: 855.3068 - val_loss: 965.6799
# Epoch 10/200
# 4/4 [==============================] - 0s 8ms/step - loss: 939.2283 - val_loss: 2509.2659
# Epoch 11/200
# 4/4 [==============================] - 0s 8ms/step - loss: 863.9006 - val_loss: 1456.2448
# Epoch 12/200
# 4/4 [==============================] - 0s 7ms/step - loss: 812.9363 - val_loss: 1796.3362
# Epoch 13/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1080.2562 - val_loss: 2436.5862
# Epoch 14/200
# 4/4 [==============================] - 0s 8ms/step - loss: 767.1889 - val_loss: 1609.7910
# Epoch 15/200
# 4/4 [==============================] - 0s 8ms/step - loss: 734.6837 - val_loss: 1789.1194
# Epoch 16/200
# 4/4 [==============================] - 0s 8ms/step - loss: 661.6520 - val_loss: 1581.3954
# Epoch 17/200
# 4/4 [==============================] - 0s 8ms/step - loss: 642.1752 - val_loss: 1629.0076
# Epoch 18/200
# 4/4 [==============================] - 0s 8ms/step - loss: 637.8314 - val_loss: 1695.7677
# Epoch 19/200
# 4/4 [==============================] - 0s 7ms/step - loss: 665.3383 - val_loss: 866.5009
# Epoch 20/200
# 4/4 [==============================] - 0s 8ms/step - loss: 677.3645 - val_loss: 1171.3967
# Epoch 21/200
# 4/4 [==============================] - 0s 9ms/step - loss: 542.8889 - val_loss: 1912.2272
# Epoch 22/200
# 4/4 [==============================] - 0s 8ms/step - loss: 703.5972 - val_loss: 1397.9944
# Epoch 23/200
# 4/4 [==============================] - 0s 8ms/step - loss: 590.2726 - val_loss: 972.1650
# Epoch 24/200
# 4/4 [==============================] - 0s 8ms/step - loss: 541.9067 - val_loss: 980.0404
# Epoch 25/200
# 4/4 [==============================] - 0s 8ms/step - loss: 519.7642 - val_loss: 1211.3761
# Epoch 26/200
# 4/4 [==============================] - 0s 8ms/step - loss: 467.2577 - val_loss: 903.3281
# Epoch 27/200
# 4/4 [==============================] - 0s 8ms/step - loss: 558.0747 - val_loss: 891.6918
# Epoch 28/200
# 4/4 [==============================] - 0s 8ms/step - loss: 400.9578 - val_loss: 641.7595
# Epoch 29/200
# 4/4 [==============================] - 0s 8ms/step - loss: 365.5363 - val_loss: 584.8014
# Epoch 30/200
# 4/4 [==============================] - 0s 8ms/step - loss: 418.0296 - val_loss: 559.6230
# Epoch 31/200
# 4/4 [==============================] - 0s 7ms/step - loss: 352.5071 - val_loss: 659.8044
# Epoch 32/200
# 4/4 [==============================] - 0s 8ms/step - loss: 339.5603 - val_loss: 685.4301
# Epoch 33/200
# 4/4 [==============================] - 0s 8ms/step - loss: 449.7514 - val_loss: 723.2766
# Epoch 34/200
# 4/4 [==============================] - 0s 8ms/step - loss: 332.6086 - val_loss: 866.5648
# Epoch 35/200
# 4/4 [==============================] - 0s 8ms/step - loss: 304.9594 - val_loss: 597.4969
# Epoch 36/200
# 4/4 [==============================] - 0s 8ms/step - loss: 392.3479 - val_loss: 520.0186
# Epoch 37/200
# 4/4 [==============================] - 0s 7ms/step - loss: 279.7086 - val_loss: 587.7837
# Epoch 38/200
# 4/4 [==============================] - 0s 8ms/step - loss: 375.7927 - val_loss: 571.2220
# Epoch 39/200
# 4/4 [==============================] - 0s 8ms/step - loss: 369.9549 - val_loss: 503.5276
# Epoch 40/200
# 4/4 [==============================] - 0s 8ms/step - loss: 319.9405 - val_loss: 471.9066
# Epoch 41/200
# 4/4 [==============================] - 0s 8ms/step - loss: 261.4729 - val_loss: 509.6068
# Epoch 42/200
# 4/4 [==============================] - 0s 8ms/step - loss: 294.1545 - val_loss: 614.5166
# Epoch 43/200
# 4/4 [==============================] - 0s 8ms/step - loss: 273.9722 - val_loss: 470.0614
# Epoch 44/200
# 4/4 [==============================] - 0s 8ms/step - loss: 255.1487 - val_loss: 688.1283
# Epoch 45/200
# 4/4 [==============================] - 0s 7ms/step - loss: 332.7828 - val_loss: 698.6544
# Epoch 46/200
# 4/4 [==============================] - 0s 8ms/step - loss: 293.7603 - val_loss: 391.7057
# Epoch 47/200
# 4/4 [==============================] - 0s 8ms/step - loss: 320.5426 - val_loss: 390.7150
# Epoch 48/200
# 4/4 [==============================] - 0s 7ms/step - loss: 255.9817 - val_loss: 402.0430
# Epoch 49/200
# 4/4 [==============================] - 0s 7ms/step - loss: 248.7362 - val_loss: 486.1979
# Epoch 50/200
# 4/4 [==============================] - 0s 8ms/step - loss: 259.6516 - val_loss: 789.0621
# Epoch 51/200
# 4/4 [==============================] - 0s 8ms/step - loss: 308.2343 - val_loss: 718.7413
# Epoch 52/200
# 4/4 [==============================] - 0s 7ms/step - loss: 260.5564 - val_loss: 622.7206
# Epoch 53/200
# 4/4 [==============================] - 0s 7ms/step - loss: 293.1636 - val_loss: 742.1625
# Epoch 54/200
# 4/4 [==============================] - 0s 8ms/step - loss: 294.6372 - val_loss: 619.8477
# Epoch 55/200
# 4/4 [==============================] - 0s 7ms/step - loss: 254.0953 - val_loss: 664.7651
# Epoch 56/200
# 4/4 [==============================] - 0s 7ms/step - loss: 231.5280 - val_loss: 672.0296
# Epoch 57/200
# 4/4 [==============================] - 0s 7ms/step - loss: 291.9766 - val_loss: 684.8167
# Epoch 58/200
# 4/4 [==============================] - 0s 7ms/step - loss: 208.9401 - val_loss: 555.4764
# Epoch 59/200
# 4/4 [==============================] - 0s 7ms/step - loss: 256.9147 - val_loss: 560.7775
# Epoch 60/200
# 4/4 [==============================] - 0s 7ms/step - loss: 201.5052 - val_loss: 587.7395
# Epoch 61/200
# 4/4 [==============================] - 0s 7ms/step - loss: 226.3178 - val_loss: 803.2906
# Epoch 62/200
# 4/4 [==============================] - 0s 7ms/step - loss: 211.3037 - val_loss: 552.2086
# Epoch 63/200
# 4/4 [==============================] - 0s 7ms/step - loss: 237.1193 - val_loss: 677.1854
# Epoch 64/200
# 4/4 [==============================] - 0s 7ms/step - loss: 250.2613 - val_loss: 596.9589
# Epoch 65/200
# 4/4 [==============================] - 0s 7ms/step - loss: 225.4114 - val_loss: 490.7865
# Epoch 66/200
# 4/4 [==============================] - 0s 7ms/step - loss: 235.6871 - val_loss: 612.5303
# Epoch 67/200
# 4/4 [==============================] - 0s 7ms/step - loss: 188.8276 - val_loss: 550.4194
# Epoch 68/200
# 4/4 [==============================] - 0s 7ms/step - loss: 249.5642 - val_loss: 566.6886
# Epoch 69/200
# 4/4 [==============================] - 0s 7ms/step - loss: 214.9469 - val_loss: 602.0020
# Epoch 70/200
# 4/4 [==============================] - 0s 7ms/step - loss: 198.4319 - val_loss: 453.5205
# Epoch 71/200
# 4/4 [==============================] - 0s 7ms/step - loss: 234.7015 - val_loss: 543.1507
# Epoch 72/200
# 4/4 [==============================] - 0s 7ms/step - loss: 203.4116 - val_loss: 441.8049
# Epoch 73/200
# 4/4 [==============================] - 0s 7ms/step - loss: 185.3374 - val_loss: 480.8615
# Epoch 74/200
# 4/4 [==============================] - 0s 7ms/step - loss: 186.3588 - val_loss: 488.8589
# Epoch 75/200
# 4/4 [==============================] - 0s 7ms/step - loss: 242.3622 - val_loss: 476.6722
# Epoch 76/200
# 4/4 [==============================] - 0s 8ms/step - loss: 224.4521 - val_loss: 472.1297
# Epoch 77/200
# 4/4 [==============================] - 0s 8ms/step - loss: 215.5105 - val_loss: 500.4470
# Epoch 78/200
# 4/4 [==============================] - 0s 7ms/step - loss: 226.8864 - val_loss: 680.7406
# Epoch 79/200
# 4/4 [==============================] - 0s 8ms/step - loss: 223.2780 - val_loss: 822.3457
# Epoch 80/200
# 4/4 [==============================] - 0s 7ms/step - loss: 225.7788 - val_loss: 734.2125
# Epoch 81/200
# 4/4 [==============================] - 0s 8ms/step - loss: 231.5855 - val_loss: 442.8655
# Epoch 82/200
# 4/4 [==============================] - 0s 8ms/step - loss: 170.6093 - val_loss: 585.0452
# Epoch 83/200
# 4/4 [==============================] - 0s 8ms/step - loss: 200.2370 - val_loss: 482.8230
# Epoch 84/200
# 4/4 [==============================] - 0s 7ms/step - loss: 161.7500 - val_loss: 477.4291
# Epoch 85/200
# 4/4 [==============================] - 0s 7ms/step - loss: 216.6809 - val_loss: 405.7799
# Epoch 86/200
# 4/4 [==============================] - 0s 7ms/step - loss: 212.0644 - val_loss: 421.7938
# Epoch 87/200
# 4/4 [==============================] - 0s 8ms/step - loss: 169.0409 - val_loss: 387.1830
# Epoch 88/200
# 4/4 [==============================] - 0s 7ms/step - loss: 230.6751 - val_loss: 398.7783
# Epoch 89/200
# 4/4 [==============================] - 0s 8ms/step - loss: 180.7056 - val_loss: 343.1306
# Epoch 90/200
# 4/4 [==============================] - 0s 7ms/step - loss: 222.1486 - val_loss: 499.3499
# Epoch 91/200
# 4/4 [==============================] - 0s 7ms/step - loss: 207.6815 - val_loss: 429.6167
# Epoch 92/200
# 4/4 [==============================] - 0s 7ms/step - loss: 198.2920 - val_loss: 385.5926
# Epoch 93/200
# 4/4 [==============================] - 0s 7ms/step - loss: 195.4985 - val_loss: 384.0670
# Epoch 94/200
# 4/4 [==============================] - 0s 7ms/step - loss: 198.1020 - val_loss: 392.7298
# Epoch 95/200
# 4/4 [==============================] - 0s 7ms/step - loss: 190.5262 - val_loss: 407.0327
# Epoch 96/200
# 4/4 [==============================] - 0s 7ms/step - loss: 160.7438 - val_loss: 407.1341
# Epoch 97/200
# 4/4 [==============================] - 0s 7ms/step - loss: 155.0746 - val_loss: 368.9182
# Epoch 98/200
# 4/4 [==============================] - 0s 7ms/step - loss: 149.2518 - val_loss: 386.2090
# Epoch 99/200
# 4/4 [==============================] - 0s 7ms/step - loss: 163.3809 - val_loss: 345.8652
# Epoch 100/200
# 4/4 [==============================] - 0s 7ms/step - loss: 164.9235 - val_loss: 400.1689
# Epoch 101/200
# 4/4 [==============================] - 0s 7ms/step - loss: 184.9207 - val_loss: 397.2725
# Epoch 102/200
# 4/4 [==============================] - 0s 7ms/step - loss: 244.9972 - val_loss: 356.7167
# Epoch 103/200
# 4/4 [==============================] - 0s 7ms/step - loss: 171.1637 - val_loss: 367.7301
# Epoch 104/200
# 4/4 [==============================] - 0s 7ms/step - loss: 176.4458 - val_loss: 351.9961
# Epoch 105/200
# 4/4 [==============================] - 0s 7ms/step - loss: 158.2763 - val_loss: 358.1353
# Epoch 106/200
# 4/4 [==============================] - 0s 7ms/step - loss: 174.9991 - val_loss: 381.4236
# Epoch 107/200
# 4/4 [==============================] - 0s 7ms/step - loss: 183.6783 - val_loss: 366.8207
# Epoch 108/200
# 4/4 [==============================] - 0s 7ms/step - loss: 184.8865 - val_loss: 366.3448
# Epoch 109/200
# 4/4 [==============================] - 0s 7ms/step - loss: 143.3820 - val_loss: 371.1886
# Epoch 110/200
# 4/4 [==============================] - 0s 7ms/step - loss: 164.4069 - val_loss: 382.1731
# Epoch 111/200
# 4/4 [==============================] - 0s 7ms/step - loss: 184.4979 - val_loss: 426.3914
# Epoch 112/200
# 4/4 [==============================] - 0s 7ms/step - loss: 173.6898 - val_loss: 409.6206
# Epoch 113/200
# 4/4 [==============================] - 0s 7ms/step - loss: 192.1187 - val_loss: 407.9836
# Epoch 114/200
# 4/4 [==============================] - 0s 7ms/step - loss: 159.1659 - val_loss: 400.6984
# Epoch 115/200
# 4/4 [==============================] - 0s 7ms/step - loss: 132.7470 - val_loss: 392.2549
# Epoch 116/200
# 4/4 [==============================] - 0s 7ms/step - loss: 150.0996 - val_loss: 363.9406
# Epoch 117/200
# 4/4 [==============================] - 0s 8ms/step - loss: 186.1195 - val_loss: 337.6342
# Epoch 118/200
# 4/4 [==============================] - 0s 8ms/step - loss: 147.8720 - val_loss: 357.0660
# Epoch 119/200
# 4/4 [==============================] - 0s 8ms/step - loss: 183.0780 - val_loss: 345.2719
# Epoch 120/200
# 4/4 [==============================] - 0s 111ms/step - loss: 168.2536 - val_loss: 352.1613
# Epoch 121/200
# 4/4 [==============================] - 0s 8ms/step - loss: 152.3501 - val_loss: 368.8413
# Epoch 122/200
# 4/4 [==============================] - 0s 8ms/step - loss: 157.5419 - val_loss: 344.5671
# Epoch 123/200
# 4/4 [==============================] - 0s 8ms/step - loss: 158.6674 - val_loss: 341.1161
# Epoch 124/200
# 4/4 [==============================] - 0s 9ms/step - loss: 172.8962 - val_loss: 334.5057
# Epoch 125/200
# 4/4 [==============================] - 0s 9ms/step - loss: 133.2701 - val_loss: 412.6064
# Epoch 126/200
# 4/4 [==============================] - 0s 8ms/step - loss: 152.3641 - val_loss: 374.1463
# Epoch 127/200
# 4/4 [==============================] - 0s 8ms/step - loss: 158.8933 - val_loss: 375.1407
# Epoch 128/200
# 4/4 [==============================] - 0s 8ms/step - loss: 154.1467 - val_loss: 362.6218
# Epoch 129/200
# 4/4 [==============================] - 0s 8ms/step - loss: 146.6341 - val_loss: 394.4688
# Epoch 130/200
# 4/4 [==============================] - 0s 9ms/step - loss: 181.2518 - val_loss: 412.9533
# Epoch 131/200
# 4/4 [==============================] - 0s 8ms/step - loss: 155.7968 - val_loss: 401.0032
# Epoch 132/200
# 4/4 [==============================] - 0s 8ms/step - loss: 138.8353 - val_loss: 384.8229
# Epoch 133/200
# 4/4 [==============================] - 0s 8ms/step - loss: 155.9085 - val_loss: 391.9904
# Epoch 134/200
# 4/4 [==============================] - 0s 8ms/step - loss: 144.8316 - val_loss: 391.6318
# Epoch 135/200
# 4/4 [==============================] - 0s 9ms/step - loss: 154.8189 - val_loss: 376.1180
# Epoch 136/200
# 4/4 [==============================] - 0s 8ms/step - loss: 143.2533 - val_loss: 366.0980
# Epoch 137/200
# 4/4 [==============================] - 0s 8ms/step - loss: 140.3400 - val_loss: 378.9710
# Epoch 138/200
# 4/4 [==============================] - 0s 8ms/step - loss: 124.1275 - val_loss: 384.0981
# Epoch 139/200
# 4/4 [==============================] - 0s 8ms/step - loss: 131.5067 - val_loss: 384.2787
# Epoch 140/200
# 4/4 [==============================] - 0s 8ms/step - loss: 105.4407 - val_loss: 380.1021
# Epoch 141/200
# 4/4 [==============================] - 0s 8ms/step - loss: 137.5311 - val_loss: 366.0162
# Epoch 142/200
# 4/4 [==============================] - 0s 8ms/step - loss: 156.8236 - val_loss: 373.5663
# Epoch 143/200
# 4/4 [==============================] - 0s 8ms/step - loss: 124.4231 - val_loss: 369.5332
# Epoch 144/200
# 4/4 [==============================] - 0s 8ms/step - loss: 144.4111 - val_loss: 390.3001
# Epoch 145/200
# 4/4 [==============================] - 0s 8ms/step - loss: 134.9249 - val_loss: 389.2014
# Epoch 146/200
# 4/4 [==============================] - 0s 8ms/step - loss: 149.9765 - val_loss: 394.1762
# Epoch 147/200
# 4/4 [==============================] - 0s 8ms/step - loss: 135.0634 - val_loss: 374.1612
# Epoch 148/200
# 4/4 [==============================] - 0s 8ms/step - loss: 109.3859 - val_loss: 363.1563
# Epoch 149/200
# 4/4 [==============================] - 0s 8ms/step - loss: 137.6115 - val_loss: 365.2840
# Epoch 150/200
# 4/4 [==============================] - 0s 8ms/step - loss: 104.2656 - val_loss: 380.6122
# Epoch 151/200
# 4/4 [==============================] - 0s 8ms/step - loss: 141.2268 - val_loss: 367.2721
# Epoch 152/200
# 4/4 [==============================] - 0s 8ms/step - loss: 129.3102 - val_loss: 378.9672
# Epoch 153/200
# 4/4 [==============================] - 0s 8ms/step - loss: 117.9504 - val_loss: 364.8299
# Epoch 154/200
# 4/4 [==============================] - 0s 8ms/step - loss: 118.2063 - val_loss: 354.5207
# Epoch 155/200
# 4/4 [==============================] - 0s 8ms/step - loss: 97.6942 - val_loss: 355.7863
# Epoch 156/200
# 4/4 [==============================] - 0s 8ms/step - loss: 142.1921 - val_loss: 358.1982
# Epoch 157/200
# 4/4 [==============================] - 0s 8ms/step - loss: 116.5317 - val_loss: 364.7438
# Epoch 158/200
# 4/4 [==============================] - 0s 8ms/step - loss: 122.7274 - val_loss: 363.7351
# Epoch 159/200
# 4/4 [==============================] - 0s 8ms/step - loss: 116.7191 - val_loss: 345.5143
# Epoch 160/200
# 4/4 [==============================] - 0s 8ms/step - loss: 114.7892 - val_loss: 371.8448
# Epoch 161/200
# 4/4 [==============================] - 0s 7ms/step - loss: 125.8097 - val_loss: 370.8575
# Epoch 162/200
# 4/4 [==============================] - 0s 7ms/step - loss: 139.4778 - val_loss: 363.4695
# Epoch 163/200
# 4/4 [==============================] - 0s 8ms/step - loss: 104.3839 - val_loss: 365.4110
# Epoch 164/200
# 4/4 [==============================] - 0s 8ms/step - loss: 147.9594 - val_loss: 350.0326
# Epoch 165/200
# 4/4 [==============================] - 0s 8ms/step - loss: 139.4259 - val_loss: 348.7226
# Epoch 166/200
# 4/4 [==============================] - 0s 8ms/step - loss: 111.3317 - val_loss: 383.8514
# Epoch 167/200
# 4/4 [==============================] - 0s 8ms/step - loss: 128.0923 - val_loss: 382.7545
# Epoch 168/200
# 4/4 [==============================] - 0s 7ms/step - loss: 172.7852 - val_loss: 360.8107
# Epoch 169/200
# 4/4 [==============================] - 0s 7ms/step - loss: 118.7322 - val_loss: 360.5567
# Epoch 170/200
# 4/4 [==============================] - 0s 7ms/step - loss: 129.2089 - val_loss: 347.6787
# Epoch 171/200
# 4/4 [==============================] - 0s 8ms/step - loss: 103.5535 - val_loss: 362.5958
# Epoch 172/200
# 4/4 [==============================] - 0s 8ms/step - loss: 109.3811 - val_loss: 338.9647
# Epoch 173/200
# 4/4 [==============================] - 0s 8ms/step - loss: 119.3730 - val_loss: 328.2197
# Epoch 174/200
# 4/4 [==============================] - 0s 7ms/step - loss: 142.4757 - val_loss: 384.2575
# Epoch 175/200
# 4/4 [==============================] - 0s 7ms/step - loss: 108.4280 - val_loss: 339.1826
# Epoch 176/200
# 4/4 [==============================] - 0s 7ms/step - loss: 92.3288 - val_loss: 329.5076
# Epoch 177/200
# 4/4 [==============================] - 0s 8ms/step - loss: 137.8672 - val_loss: 335.0416
# Epoch 178/200
# 4/4 [==============================] - 0s 8ms/step - loss: 124.2354 - val_loss: 319.6772
# Epoch 179/200
# 4/4 [==============================] - 0s 9ms/step - loss: 140.7240 - val_loss: 313.6519
# Epoch 180/200
# 4/4 [==============================] - 0s 8ms/step - loss: 120.7179 - val_loss: 320.7545
# Epoch 181/200
# 4/4 [==============================] - 0s 8ms/step - loss: 101.9438 - val_loss: 314.7640
# Epoch 182/200
# 4/4 [==============================] - 0s 8ms/step - loss: 89.8569 - val_loss: 314.8318
# Epoch 183/200
# 4/4 [==============================] - 0s 9ms/step - loss: 79.3725 - val_loss: 330.2302
# Epoch 184/200
# 4/4 [==============================] - 0s 9ms/step - loss: 115.7108 - val_loss: 348.6019
# Epoch 185/200
# 4/4 [==============================] - 0s 9ms/step - loss: 145.8573 - val_loss: 320.0890
# Epoch 186/200
# 4/4 [==============================] - 0s 9ms/step - loss: 123.4593 - val_loss: 331.7127
# Epoch 187/200
# 4/4 [==============================] - 0s 8ms/step - loss: 127.2658 - val_loss: 327.5145
# Epoch 188/200
# 4/4 [==============================] - 0s 8ms/step - loss: 100.2474 - val_loss: 335.0468
# Epoch 189/200
# 4/4 [==============================] - 0s 8ms/step - loss: 142.1924 - val_loss: 326.1362
# Epoch 190/200
# 4/4 [==============================] - 0s 8ms/step - loss: 124.5061 - val_loss: 346.5090
# Epoch 191/200
# 4/4 [==============================] - 0s 8ms/step - loss: 124.8798 - val_loss: 339.1326
# Epoch 192/200
# 4/4 [==============================] - 0s 9ms/step - loss: 112.8985 - val_loss: 345.1338
# Epoch 193/200
# 4/4 [==============================] - 0s 8ms/step - loss: 95.3925 - val_loss: 344.5091
# Epoch 194/200
# 4/4 [==============================] - 0s 8ms/step - loss: 103.8342 - val_loss: 295.9380
# Epoch 195/200
# 4/4 [==============================] - 0s 8ms/step - loss: 95.5815 - val_loss: 307.8656
# Epoch 196/200
# 4/4 [==============================] - 0s 8ms/step - loss: 97.4712 - val_loss: 301.8896
# Epoch 197/200
# 4/4 [==============================] - 0s 8ms/step - loss: 104.5198 - val_loss: 272.6694
# Epoch 198/200
# 4/4 [==============================] - 0s 8ms/step - loss: 115.7689 - val_loss: 314.5003
# Epoch 199/200
# 4/4 [==============================] - 0s 8ms/step - loss: 101.3199 - val_loss: 299.4969
# Epoch 200/200
# 4/4 [==============================] - 0s 8ms/step - loss: 90.1035 - val_loss: 315.9026

# %%
def mae_mape_calculator(model, test_input, test_target, start_target):
    
    errors = []
    error_percent = []
    results_data = []

    for i in range(len(test_target)):
        prediction = model.predict(test_input[i:i+1])
        target = test_target[start_target + i]
        error = np.abs(prediction - target)
        errors.append(error)
        error_percent.append(error/target)
        results_data.append([f"Month-{i + 1}", 
                             prediction[0][0], 
                             target, 
                             error[0][0]])

    df_results = pd.DataFrame(results_data, columns=["Month", "Prediction", "Target", "Error"])

    mae = np.mean(errors)
    mape = np.mean(error_percent) 

    return df_results, mae, mape

# %%
df_results, mae, mape = mae_mape_calculator(trained_model, 
                                            reshaped_test, 
                                            reshaped_test_target, 
                                            start_index)
pd.set_option('display.max_columns', None)
df_results.T
# Out:
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
#                     0           1           2           3           4   \
# Month          Month-1     Month-2     Month-3     Month-4     Month-5
# Prediction  267.058441  273.053833  270.918243  271.359009  261.444244
# Target         250.101     277.528     270.092     278.146     257.458
# Error        16.957443    4.474182    0.826233    6.786987    3.986237
#
#                    5           6           7           8           9   \
# Month         Month-6     Month-7     Month-8     Month-9    Month-10
# Prediction  259.40802  259.603485  254.806015  261.128296  256.931427
# Target        231.748     268.336     223.453     241.464     238.901
# Error       27.660019    8.732513   31.353012   19.664291   18.030426
#
#                    10          11          12          13          14  \
# Month        Month-11    Month-12    Month-13    Month-14    Month-15
# Prediction  258.60788  257.038483  259.930878  267.422394  264.338623
# Target        191.989     272.452     261.009     292.688     258.881
# Error       66.618881   15.413513    1.078125   25.265594    5.457611
#
#                     15          16          17         18          19  \
# Month         Month-16    Month-17    Month-18   Month-19    Month-20
# Prediction  267.492096  263.294678  262.755859   263.0979  260.327911
# Target         276.879     255.774     208.326    291.428      249.43
# Error         9.386902    7.520676   54.429855  28.330109   10.897919
#
#                     20          21          22          23          24  \
# Month         Month-21    Month-22    Month-23    Month-24    Month-25
# Prediction  263.876251  259.322693  262.722961  257.560669  258.806152
# Target         241.612     252.303     281.912     200.213     270.511
# Error        22.264252    7.019699   19.189026   57.347672   11.704834
#
#                    25          26          27          28          29
# Month        Month-26    Month-27    Month-28    Month-29    Month-30
# Prediction  263.41748  259.185669  258.896667  255.515213  255.315643
# Target        281.466     285.535     328.259     298.078     264.838
# Error       18.048523   26.349335   69.362335    42.56279    9.522369

# %%
display(mae)
display(mape)
# Out:
# 21.541378
# 0.08735879

# %%
def year_mae_mape_calculator(model, test_input, test_target, start_target):
    
    errors = []
    error_percent = []
    
    target_sum = 0
    prediction_sum = 0
    
    for i in range(len(test_target)):
        if i % 12 == 0 and i != 0:
            error = np.abs(target_sum - prediction_sum)
            errors.append(error)
            error_percent.append(error / target_sum)
            print(f"Ano-{i%12}: |Prediction{prediction_sum} - Target[{target_sum}]| =  Error: {error}; MAPE:{abs(prediction_sum - target_sum)/target_sum}")
            target_sum = 0
            prediction_sum = 0
            
        prediction = model.predict(test_input[i:i+1])
        target_sum += test_target[start_target + i]
        prediction_sum += prediction
        
    error = np.abs(target_sum - prediction_sum)
    errors.append(error)
    error_percent.append(error / target_sum)
    print(f"Ano-{i%12}: |Prediction{prediction_sum} - Target[{target_sum}]| =  Error: {error}; MAPE:{abs(prediction_sum - target_sum)/target_sum}")
        
    mae = np.mean(errors)
    mape = np.mean(error_percent) 

    return errors, mae, mape

# %%
errors, mae, mape = year_mae_mape_calculator(trained_model, 
                                             reshaped_test, 
                                             reshaped_test_target, 
                                             start_index)
display(errors)
display(mae)
display(mape)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Ano-0: |Prediction[[3151.3572]] - Target[3001.6679999999997]| =  Error: [[149.68921]]; MAPE:[[0.04986868]]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# Ano-0: |Prediction[[3152.143]] - Target[3070.4549999999995]| =  Error: [[81.68799]]; MAPE:[[0.02660452]]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Ano-5: |Prediction[[1551.1368]] - Target[1728.6870000000001]| =  Error: [[177.55017]]; MAPE:[[0.10270811]]
# [array([[149.68921]], dtype=float32),
#  array([[81.68799]], dtype=float32),
#  array([[177.55017]], dtype=float32)]
# 136.30913
# 0.059727103
