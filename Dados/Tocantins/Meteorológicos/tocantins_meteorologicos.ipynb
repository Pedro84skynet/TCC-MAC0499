# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('tocantins_variacao_climatica')
df
# Out:
#          State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Tocantins  2005-01                3.522222                977.149530
# 1    Tocantins  2005-02                3.200000                977.230729
# 2    Tocantins  2005-03                2.234146                978.760349
# 3    Tocantins  2005-04                2.532394                978.607222
# 4    Tocantins  2005-05                2.063636                979.337903
# ..         ...      ...                     ...                       ...
# 211  Tocantins  2022-08                0.000000                979.506720
# 212  Tocantins  2022-09                2.583333                978.230417
# 213  Tocantins  2022-10                1.920833                977.834677
# 214  Tocantins  2022-11                3.348352                980.098681
# 215  Tocantins  2022-12                2.896117                979.973656
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                            1316.632178                        26.295363
# 1                            1409.292541                        26.669048
# 2                            1190.276942                        25.863374
# 3                            1435.946175                        27.125764
# 4                            1360.070161                        26.695296
# ..                                   ...                              ...
# 211                          1613.101613                        29.646102
# 212                          1534.255220                        30.438611
# 213                          1404.846316                        29.652890
# 214                          1212.196377                        26.178194
# 215                          1267.753972                        25.879503
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     21.711962                  77.483871         1.613777
# 1                     21.978497                  76.855655         1.688318
# 2                     22.078696                  80.649866         1.489651
# 3                     21.349236                  72.813889         1.707708
# 4                     19.244489                  65.849462         2.005914
# ..                          ...                        ...              ...
# 211                   11.486962                  35.232527         2.142608
# 212                   13.665278                  39.919444         1.475000
# 213                   17.807460                  52.987231         1.083065
# 214                   20.905694                  74.043750         1.434306
# 215                   21.537836                  78.211694         1.052755
#
#      Year
# 0    2005
# 1    2005
# 2    2005
# 3    2005
# 4    2005
# ..    ...
# 211  2022
# 212  2022
# 213  2022
# 214  2022
# 215  2022
#
# [216 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
