# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
ditrito_federal_df = pd.read_csv('ditrito_federal_variacao_climatica')
ditrito_federal_df
# Out:
#                 State     Date  Precipitation (mm/day)  \
# 0    Distrito Federal  2001-01                1.976000
# 1    Distrito Federal  2001-02                2.888235
# 2    Distrito Federal  2001-03                1.609600
# 3    Distrito Federal  2001-04                4.152941
# 4    Distrito Federal  2001-05                1.547826
# ..                ...      ...                     ...
# 259  Distrito Federal  2022-08                0.000000
# 260  Distrito Federal  2022-09                2.376471
# 261  Distrito Federal  2022-10                1.863158
# 262  Distrito Federal  2022-11                3.894545
# 263  Distrito Federal  2022-12                2.565079
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 0                  886.802957                          1753.685065
# 1                  886.119568                          1745.066667
# 2                  886.866129                          1346.989975
# 3                  887.774653                          1685.873596
# 4                  887.783401                          1416.255376
# ..                        ...                                  ...
# 259                889.055780                          1625.311688
# 260                887.612639                          1643.547790
# 261                886.530645                          1505.639141
# 262                885.288889                          1289.977381
# 263                884.845968                          1170.772979
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 0                          22.588508                   15.979435
# 1                          22.428795                   15.532664
# 2                          21.098253                   16.825269
# 3                          21.776319                   14.857639
# 4                          20.782930                   13.869624
# ..                               ...                         ...
# 259                        21.149194                    7.294489
# 260                        22.905139                    9.822778
# 261                        23.680376                   12.117876
# 262                        20.657361                   16.049028
# 263                        20.815726                   17.213441
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Year
# 0                    68.475806         2.522379  2001
# 1                    67.927083         2.022768  2001
# 2                    78.236559         2.085618  2001
# 3                    66.802083         2.321389  2001
# 4                    66.650538         2.038172  2001
# ..                         ...              ...   ...
# 259                  43.349462         2.520430  2022
# 260                  49.002778         2.363611  2022
# 261                  52.651882         2.429839  2022
# 262                  76.938889         2.151806  2022
# 263                  81.080645         2.233199  2022
#
# [264 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(ditrito_federal_df.columns):
    if i > 1:
        plot_column(ditrito_federal_df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(ditrito_federal_df.columns):
#       3     if i > 1:
# ----> 4         plot_column(ditrito_federal_df, column, color=colors[i])
#
# IndexError: list index out of range
