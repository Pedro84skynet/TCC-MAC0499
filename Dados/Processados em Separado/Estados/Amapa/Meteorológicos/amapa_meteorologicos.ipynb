# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('amapa_variacao_climatica')
df
# Out:
#      State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Amapá  2009-01                2.432740               1010.053629
# 1    Amapá  2009-02                2.369547               1009.432738
# 2    Amapá  2009-03                1.571233               1009.268952
# 3    Amapá  2009-04                1.436364               1010.566944
# 4    Amapá  2009-05                1.694624               1010.828763
# ..     ...      ...                     ...                       ...
# 151  Amapá  2021-08                0.000000                  0.000000
# 152  Amapá  2021-09                0.000000                  0.000000
# 153  Amapá  2021-10                0.000000                  0.000000
# 154  Amapá  2021-11                0.000000                  0.000000
# 155  Amapá  2021-12                0.000000                  0.000000
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                             841.374065                        24.456116
# 1                             915.869780                        24.570833
# 2                            1138.230025                        25.154032
# 3                            1283.503077                        25.463194
# 4                            1206.279653                        25.431855
# ..                                   ...                              ...
# 151                             0.000000                         0.000000
# 152                             0.000000                         0.000000
# 153                             0.000000                         0.000000
# 154                             0.000000                         0.000000
# 155                             0.000000                         0.000000
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     22.932997                  91.672715         0.967944
# 1                     22.895685                  90.933036         1.094196
# 2                     22.854301                  88.052419         1.072446
# 3                     22.707361                  85.956944         1.158889
# 4                     22.579301                  85.458333         1.231720
# ..                          ...                        ...              ...
# 151                    0.000000                   0.000000         0.000000
# 152                    0.000000                   0.000000         0.000000
# 153                    0.000000                   0.000000         0.000000
# 154                    0.000000                   0.000000         0.000000
# 155                    0.000000                   0.000000         0.000000
#
#      Year
# 0    2009
# 1    2009
# 2    2009
# 3    2009
# 4    2009
# ..    ...
# 151  2021
# 152  2021
# 153  2021
# 154  2021
# 155  2021
#
# [156 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [8], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
