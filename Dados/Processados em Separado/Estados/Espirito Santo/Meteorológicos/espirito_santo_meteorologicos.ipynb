# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('espirito_santo_variacao_climatica')
df
# Out:
#               State     Date  Precipitation (mm/day)  \
# 0    Espírito Santo  2007-01                2.390588
# 1    Espírito Santo  2007-02                1.586885
# 2    Espírito Santo  2007-03                1.400000
# 3    Espírito Santo  2007-04                1.990323
# 4    Espírito Santo  2007-05                0.945455
# ..              ...      ...                     ...
# 187  Espírito Santo  2022-08                0.534783
# 188  Espírito Santo  2022-09                1.213333
# 189  Espírito Santo  2022-10                1.591379
# 190  Espírito Santo  2022-11                2.057485
# 191  Espírito Santo  2022-12                1.763636
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 0                 1012.175403                          1355.939723
# 1                 1013.580357                          1493.362016
# 2                 1014.417809                          1828.861097
# 3                 1015.052639                          1382.895699
# 4                 1016.684677                          1309.241484
# ..                        ...                                  ...
# 187               1020.100672                           888.911579
# 188               1018.190000                           965.435641
# 189               1015.804906                          1360.492462
# 190               1014.015486                          1150.846835
# 191               1012.278091                          1126.395116
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 0                          26.349059                   22.150403
# 1                          25.759226                   21.746057
# 2                          26.654503                   21.844288
# 3                          25.347917                   21.465139
# 4                          22.873387                   18.046237
# ..                               ...                         ...
# 187                        22.017675                   16.202083
# 188                        22.287292                   16.512500
# 189                        24.642272                   19.592809
# 190                        23.718194                   18.929861
# 191                        24.890927                   20.969556
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Year
# 0                    78.939516         2.293145  2007
# 1                    79.989583         1.843676  2007
# 2                    76.806452         1.898723  2007
# 3                    80.665278         1.685139  2007
# 4                    75.899866         1.919758  2007
# ..                         ...              ...   ...
# 187                  71.532930         1.696102  2022
# 188                  71.424306         1.632917  2022
# 189                  74.919355         1.697513  2022
# 190                  76.122917         1.658125  2022
# 191                  80.364247         1.385417  2022
#
# [192 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
