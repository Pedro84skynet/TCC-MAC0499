# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('roraima_variacao_climatica')
df
# Out:
#        State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Roraima  2011-01                1.308333               1000.012769
# 1    Roraima  2011-02                2.592000               1000.750298
# 2    Roraima  2011-03                2.783333               1000.883871
# 3    Roraima  2011-04                1.255556               1001.200139
# 4    Roraima  2011-05                4.041558               1001.634140
# ..       ...      ...                     ...                       ...
# 139  Roraima  2022-08                0.000000               1002.602957
# 140  Roraima  2022-09                0.000000               1001.561528
# 141  Roraima  2022-10                0.000000               1000.725134
# 142  Roraima  2022-11                0.000000               1000.963958
# 143  Roraima  2022-12                1.744828               1000.761559
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                            1500.343878                        27.281183
# 1                            1554.615702                        28.050595
# 2                            1400.732487                        26.989718
# 3                            1622.574734                        27.855278
# 4                            1035.017692                        25.871774
# ..                                   ...                              ...
# 139                          1448.011724                        26.919624
# 140                          1601.668204                        27.544444
# 141                          1593.557531                        27.804973
# 142                          1401.387042                        27.011250
# 143                          1485.540642                        26.578763
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     20.047715                  66.502688         2.370161
# 1                     20.513839                  65.555060         2.256250
# 2                     21.031317                  71.602823         2.061626
# 3                     21.111389                  68.666667         2.004583
# 4                     22.758602                  83.971774         1.294758
# ..                          ...                        ...              ...
# 139                   20.500000                  62.000000         3.728421
# 140                   20.500000                  62.000000         2.911389
# 141                   20.500000                  62.000000         2.094357
# 142                   20.500000                  62.000000         1.588925
# 143                   20.065591                  68.661290         1.862567
#
#      Year
# 0    2011
# 1    2011
# 2    2011
# 3    2011
# 4    2011
# ..    ...
# 139  2022
# 140  2022
# 141  2022
# 142  2022
# 143  2022
#
# [144 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
