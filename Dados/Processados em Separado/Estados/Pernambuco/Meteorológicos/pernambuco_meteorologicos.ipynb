# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('pernambuco_variacao_climatica')
df
# Out:
#           State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Pernambuco  2005-01                2.225000               1010.447379
# 1    Pernambuco  2005-02                1.728000               1010.175446
# 2    Pernambuco  2005-03                2.030000               1010.908333
# 3    Pernambuco  2005-04                2.386301               1011.233542
# 4    Pernambuco  2005-05                2.921111               1011.939516
# ..          ...      ...                     ...                       ...
# 211  Pernambuco  2022-08                0.000000                  0.000000
# 212  Pernambuco  2022-09                0.000000                  0.000000
# 213  Pernambuco  2022-10                0.000000                  0.000000
# 214  Pernambuco  2022-11                0.000000                  0.000000
# 215  Pernambuco  2022-12                0.000000                  0.000000
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                            1974.580840                        27.494825
# 1                            1826.049267                        27.497693
# 2                            1797.443501                        27.920296
# 3                            1752.695238                        26.972153
# 4                            1455.412113                        25.531317
# ..                                   ...                              ...
# 211                             0.000000                         0.000000
# 212                             0.000000                         0.000000
# 213                             0.000000                         0.000000
# 214                             0.000000                         0.000000
# 215                             0.000000                         0.000000
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     21.056250                  68.994624         2.354234
# 1                     21.981696                  72.976935         2.205804
# 2                     21.994153                  71.304435         2.029637
# 3                     22.211736                  76.162500         1.863472
# 4                     22.227285                  82.677419         1.475403
# ..                          ...                        ...              ...
# 211                    0.000000                   0.000000         0.000000
# 212                    0.000000                   0.000000         0.000000
# 213                    0.000000                   0.000000         0.000000
# 214                    0.000000                   0.000000         0.000000
# 215                    0.000000                   0.000000         0.000000
#
#      Year
# 0    2005
# 1    2005
# 2    2005
# 3    2005
# 4    2005
# ..    ...
# 211  2022
# 212  2022
# 213  2022
# 214  2022
# 215  2022
#
# [216 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
