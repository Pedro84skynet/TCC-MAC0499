# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
ditrito_federal_df = pd.read_csv('amazonia_variacao_climatica')
ditrito_federal_df
# Out:
#         State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Amazonia  2001-01                1.109783               1004.775707
# 1    Amazonia  2001-02                3.613793               1003.496465
# 2    Amazonia  2001-03                2.721951               1003.974933
# 3    Amazonia  2001-04                2.413514               1004.399861
# 4    Amazonia  2001-05                4.263830               1004.358871
# ..        ...      ...                     ...                       ...
# 259  Amazonia  2022-08                2.585714               1005.365524
# 260  Amazonia  2022-09                1.200000               1004.169306
# 261  Amazonia  2022-10                5.090323               1003.585013
# 262  Amazonia  2022-11                3.229032               1003.586250
# 263  Amazonia  2022-12                5.108108               1003.371438
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                            1232.752294                        25.632534
# 1                            1383.290698                        24.884739
# 2                            1342.827320                        26.204301
# 3                            1335.930939                        25.939306
# 4                            1378.290667                        26.595296
# ..                                   ...                              ...
# 259                          1230.134332                        28.923185
# 260                          1300.817632                        29.763819
# 261                          1231.088729                        28.751747
# 262                          1141.277970                        28.270833
# 263                           990.830310                        27.328831
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     22.817824                  85.058364         1.099922
# 1                     22.652886                  87.849817         1.590191
# 2                     22.771505                  82.501344         1.273790
# 3                     23.140694                  85.202778         1.134306
# 4                     23.564785                  84.209677         0.985887
# ..                          ...                        ...              ...
# 259                   21.063777                  64.052419         1.486895
# 260                   21.083333                  61.696528         1.333472
# 261                   21.678360                  67.610215         1.454032
# 262                   21.824653                  69.468750         1.422292
# 263                   22.928159                  78.112903         1.279503
#
#      Year
# 0    2001
# 1    2001
# 2    2001
# 3    2001
# 4    2001
# ..    ...
# 259  2022
# 260  2022
# 261  2022
# 262  2022
# 263  2022
#
# [264 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(ditrito_federal_df.columns):
    if i > 1:
        plot_column(ditrito_federal_df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(ditrito_federal_df.columns):
#       3     if i > 1:
# ----> 4         plot_column(ditrito_federal_df, column, color=colors[i])
#
# IndexError: list index out of range
