# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('mato_grosso_do_sul_variacao_climatica')
df
# Out:
#                   State     Date  Precipitation (mm/day)  \
# 0    Mato Grosso do Sul  2002-01                2.707843
# 1    Mato Grosso do Sul  2002-02                3.052941
# 2    Mato Grosso do Sul  2002-03                2.306977
# 3    Mato Grosso do Sul  2002-04                4.016667
# 4    Mato Grosso do Sul  2002-05                3.966667
# ..                  ...      ...                     ...
# 247  Mato Grosso do Sul  2022-08                9.200000
# 248  Mato Grosso do Sul  2022-09                3.225926
# 249  Mato Grosso do Sul  2022-10                2.207692
# 250  Mato Grosso do Sul  2022-11                3.956522
# 251  Mato Grosso do Sul  2022-12                3.329412
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 0                  950.084879                          1693.096154
# 1                  951.359598                          1499.114943
# 2                  951.806855                          1576.356061
# 3                  952.125278                          1487.410053
# 4                  953.536761                          1360.140401
# ..                        ...                                  ...
# 247                960.172623                          1541.241875
# 248                953.213750                          1284.778338
# 249                951.840591                          1512.931829
# 250                951.601042                          1794.015081
# 251                949.231250                          1497.177283
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 0                          25.433065                   19.206788
# 1                          25.367113                   18.467113
# 2                          25.672917                   20.170027
# 3                          25.772292                   17.595972
# 4                          23.300202                   15.904435
# ..                               ...                         ...
# 247                        19.240284                    5.465645
# 248                        22.850278                   14.271528
# 249                        24.204973                   16.577957
# 250                        24.112778                   13.042639
# 251                        25.680981                   19.220430
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Year
# 0                    70.484543         3.331989  2002
# 1                    69.276042         2.779836  2002
# 2                    73.420027         2.423092  2002
# 3                    63.502083         2.656427  2002
# 4                    65.586694         3.129830  2002
# ..                         ...              ...   ...
# 247                  41.763019         5.098427  2022
# 248                  61.837500         3.713056  2022
# 249                  65.358871         3.053763  2022
# 250                  53.342361         3.397569  2022
# 251                  69.439516         2.657325  2022
#
# [252 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
