# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('rondonia_variacao_climatica')
df
# Out:
#         State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Rondônia  2008-01                3.153846                999.851478
# 1    Rondônia  2008-02                2.716842               1000.833046
# 2    Rondônia  2008-03                2.538400               1000.614046
# 3    Rondônia  2008-04                3.106024                999.790417
# 4    Rondônia  2008-05                3.289655               1002.105712
# ..        ...      ...                     ...                       ...
# 175  Rondônia  2022-08                1.930000               1002.125403
# 176  Rondônia  2022-09                3.477778               1000.544028
# 177  Rondônia  2022-10                3.955882                999.967944
# 178  Rondônia  2022-11                2.554098                999.883125
# 179  Rondônia  2022-12                2.484706                999.340995
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                            1191.581203                        25.334341
# 1                            1191.752033                        25.201868
# 2                            1130.547207                        25.123858
# 3                            1252.292157                        25.606875
# 4                            1213.326685                        24.766734
# ..                                   ...                              ...
# 175                          1385.649510                        26.558199
# 176                          1513.375127                        28.138333
# 177                          1374.570642                        27.020497
# 178                          1432.826540                        26.422639
# 179                          1184.020682                        26.078226
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     22.626882                  85.885753         1.449261
# 1                     22.582830                  86.320402         1.389121
# 2                     22.559879                  86.609543         1.612454
# 3                     22.722083                  85.290278         1.740174
# 4                     21.458669                  83.354167         1.867895
# ..                          ...                        ...              ...
# 175                   21.100000                  82.000000         1.494892
# 176                   21.100000                  82.000000         1.574444
# 177                   21.100000                  82.000000         1.454570
# 178                   21.100000                  82.000000         1.513403
# 179                   21.100000                  82.000000         1.410753
#
#      Year
# 0    2008
# 1    2008
# 2    2008
# 3    2008
# 4    2008
# ..    ...
# 175  2022
# 176  2022
# 177  2022
# 178  2022
# 179  2022
#
# [180 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
