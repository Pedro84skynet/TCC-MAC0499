# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('para_variacao_climatica')
df
# Out:
#     State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Pará  2004-01                3.410909               1008.145161
# 1    Pará  2004-02                3.634426               1009.341307
# 2    Pará  2004-03                3.144865               1008.577688
# 3    Pará  2004-04                3.552239               1008.775139
# 4    Pará  2004-05                2.176515               1009.050411
# ..    ...      ...                     ...                       ...
# 223  Pará  2022-08                4.395238               1009.556788
# 224  Pará  2022-09                4.468085               1009.036875
# 225  Pará  2022-10                3.741176               1007.850605
# 226  Pará  2022-11                4.235556               1007.733611
# 227  Pará  2022-12                2.870339               1007.545027
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                           12174.851117                        26.435215
# 1                            6896.012132                        25.183549
# 2                            6033.271724                        25.552016
# 3                            8591.239748                        26.247778
# 4                           13779.308782                        28.638784
# ..                                   ...                              ...
# 223                          1459.381401                        27.754570
# 224                          1435.374576                        27.823750
# 225                          1332.569363                        27.739987
# 226                          1233.017690                        27.167986
# 227                          1078.438073                        26.839382
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     23.286559                  83.649866         1.262231
# 1                     23.168606                  89.061063         0.854813
# 2                     23.408065                  88.517473         0.818011
# 3                     23.489653                  85.743750         0.846389
# 4                     23.483236                  74.869549         1.322543
# ..                          ...                        ...              ...
# 223                   23.383132                  78.680108         1.320901
# 224                   23.480486                  78.540278         1.332153
# 225                   23.643817                  79.621640         1.210081
# 226                   23.797986                  82.998611         0.879653
# 227                   23.932863                  85.243952         0.820161
#
#      Year
# 0    2004
# 1    2004
# 2    2004
# 3    2004
# 4    2004
# ..    ...
# 223  2022
# 224  2022
# 225  2022
# 226  2022
# 227  2022
#
# [228 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
