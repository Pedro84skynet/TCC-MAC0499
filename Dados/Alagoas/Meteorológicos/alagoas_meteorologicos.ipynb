# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('alagoas_variacao_climatica')
df
# Out:
#        State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Alagoas  2004-01                2.318644               1001.663642
# 1    Alagoas  2004-02                1.802632               1002.845474
# 2    Alagoas  2004-03                2.450000               1002.485349
# 3    Alagoas  2004-04                1.520408               1003.099653
# 4    Alagoas  2004-05                1.628333               1004.486694
# ..       ...      ...                     ...                       ...
# 223  Alagoas  2022-08                1.535484               1007.842137
# 224  Alagoas  2022-09                1.016667               1006.850833
# 225  Alagoas  2022-10                1.885106               1005.286828
# 226  Alagoas  2022-11                2.282353               1003.191944
# 227  Alagoas  2022-12                1.671698               1003.025269
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                            1358.580645                        25.864852
# 1                             623.150327                        25.967098
# 2                             848.445946                        26.126210
# 3                            1156.685393                        25.690347
# 4                            1032.648000                        25.082258
# ..                                   ...                              ...
# 223                          1427.304969                        23.906586
# 224                          1532.253581                        24.113333
# 225                          1669.138916                        25.354301
# 226                          1561.671602                        25.728194
# 227                          1749.838350                        26.268280
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     22.081653                  80.643817         2.651411
# 1                     21.945474                  79.600575         2.431106
# 2                     21.797581                  78.266129         2.451478
# 3                     21.976319                  80.873611         2.140000
# 4                     21.381989                  80.975806         2.040054
# ..                          ...                        ...              ...
# 223                   20.900000                  83.000000         2.490995
# 224                   20.599167                  82.220833         2.343889
# 225                   21.268011                  79.462366         2.817608
# 226                   22.379861                  83.294444         2.875278
# 227                   22.483737                  81.301075         3.144355
#
#      Year
# 0    2004
# 1    2004
# 2    2004
# 3    2004
# 4    2004
# ..    ...
# 223  2022
# 224  2022
# 225  2022
# 226  2022
# 227  2022
#
# [228 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
