# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('piaui_variacao_climatica')
df
# Out:
#      State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Piauí  2005-01                0.000000                999.600000
# 1    Piauí  2005-02                0.000000                999.600000
# 2    Piauí  2005-03                0.000000                999.600000
# 3    Piauí  2005-04                0.000000                999.600000
# 4    Piauí  2005-05                0.000000               1001.058333
# ..     ...      ...                     ...                       ...
# 211  Piauí  2022-08                1.000000               1004.087769
# 212  Piauí  2022-09                4.066667               1003.100417
# 213  Piauí  2022-10                0.836364               1001.601210
# 214  Piauí  2022-11                2.493878               1001.748333
# 215  Piauí  2022-12                4.391045               1001.523387
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                               0.000000                        32.800000
# 1                               0.000000                        32.800000
# 2                               0.000000                        32.800000
# 3                               0.000000                        32.800000
# 4                            1039.351163                        29.419220
# ..                                   ...                              ...
# 211                          1358.825806                        27.112500
# 212                          1436.276982                        28.667361
# 213                          1418.442574                        29.607661
# 214                          1133.340609                        27.437639
# 215                          1156.253171                        27.116398
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     28.400000                  78.000000         1.000000
# 1                     28.400000                  78.000000         1.000000
# 2                     28.400000                  78.000000         1.000000
# 3                     28.400000                  78.000000         1.000000
# 4                     24.817204                  77.459677         1.332124
# ..                          ...                        ...              ...
# 211                   17.391398                  60.380376         1.206720
# 212                   18.233194                  57.672222         1.322639
# 213                   18.772446                  56.497312         1.412097
# 214                   21.256806                  71.512500         1.100139
# 215                   21.457124                  73.752688         1.013038
#
#      Year
# 0    2005
# 1    2005
# 2    2005
# 3    2005
# 4    2005
# ..    ...
# 211  2022
# 212  2022
# 213  2022
# 214  2022
# 215  2022
#
# [216 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
