# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('goiais_variacao_climatica')
df
# Out:
#       State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Goiais  2002-01                2.174627                927.198387
# 1    Goiais  2002-02                2.313592                931.371726
# 2    Goiais  2002-03                3.090411                931.974933
# 3    Goiais  2002-04                2.342857                931.850694
# 4    Goiais  2002-05                0.666667                933.188239
# ..      ...      ...                     ...                       ...
# 247  Goiais  2022-08                0.000000                933.960618
# 248  Goiais  2022-09                1.876190                932.091250
# 249  Goiais  2022-10                2.289362                931.093817
# 250  Goiais  2022-11                1.675000                930.130417
# 251  Goiais  2022-12                2.061468                929.598522
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                            1537.462264                        24.632527
# 1                            1393.604972                        23.515476
# 2                            1571.398496                        24.085081
# 3                            1653.937500                        24.021319
# 4                            1468.137466                        22.221371
# ..                                   ...                              ...
# 247                          1518.691667                        23.535887
# 248                          1439.491781                        26.035833
# 249                          1510.292346                        25.538710
# 250                          1399.364439                        23.690694
# 251                          1231.739492                        23.507124
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     20.448522                  78.645833         1.210685
# 1                     19.421577                  79.701637         1.078646
# 2                     18.536694                  73.821237         1.265188
# 3                     16.810764                  67.463194         1.460833
# 4                     14.759341                  66.495968         1.378629
# ..                          ...                        ...              ...
# 247                    7.655645                  40.787634         1.285887
# 248                   11.022917                  45.341667         1.201667
# 249                   14.866398                  57.430108         1.042608
# 250                   16.724306                  68.233333         1.089028
# 251                   19.032124                  77.795699         0.841801
#
#      Year
# 0    2002
# 1    2002
# 2    2002
# 3    2002
# 4    2002
# ..    ...
# 247  2022
# 248  2022
# 249  2022
# 250  2022
# 251  2022
#
# [252 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [5], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
