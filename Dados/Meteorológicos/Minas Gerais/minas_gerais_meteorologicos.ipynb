# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('minas_gerais_variacao_climatica')
df
# Out:
#             State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Minas Gerais  2003-01                0.000000                889.600000
# 1    Minas Gerais  2003-02                0.000000                889.600000
# 2    Minas Gerais  2003-03                2.714286                889.238038
# 3    Minas Gerais  2003-04                1.607692                889.148542
# 4    Minas Gerais  2003-05                1.557576                889.869825
# ..            ...      ...                     ...                       ...
# 235  Minas Gerais  2022-08                1.420000                891.056989
# 236  Minas Gerais  2022-09                2.052632                889.312917
# 237  Minas Gerais  2022-10                2.969697                888.110215
# 238  Minas Gerais  2022-11                4.076923                886.693889
# 239  Minas Gerais  2022-12                1.866286                885.684409
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                               0.000000                        18.600000
# 1                               0.000000                        18.600000
# 2                            1359.149533                        19.012097
# 3                            1332.579096                        18.974236
# 4                            1188.773026                        16.085282
# ..                                   ...                              ...
# 235                           717.201609                        15.652957
# 236                           947.169333                        16.939792
# 237                          1362.256020                        19.585753
# 238                          1221.958696                        17.682917
# 239                          1044.868337                        18.995565
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     16.700000                  89.000000         0.300000
# 1                     16.700000                  89.000000         0.300000
# 2                     16.322849                  85.326613         0.300000
# 3                     14.949306                  79.213194         0.300000
# 4                     11.437030                  76.473790         0.300000
# ..                          ...                        ...              ...
# 235                   10.203965                  72.761425         2.231519
# 236                   11.569792                  74.500000         2.278819
# 237                   15.030108                  77.603495         1.948790
# 238                   14.442639                  82.947222         2.222778
# 239                   16.445968                  86.477151         1.937097
#
#      Year
# 0    2003
# 1    2003
# 2    2003
# 3    2003
# 4    2003
# ..    ...
# 235  2022
# 236  2022
# 237  2022
# 238  2022
# 239  2022
#
# [240 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
