# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('maranhao_variacao_climatica')
df
# Out:
#         State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Maranhao  2004-01                3.310400               1004.401747
# 1    Maranhao  2004-02                2.948750               1005.394037
# 2    Maranhao  2004-03                2.638849               1004.637231
# 3    Maranhao  2004-04                4.196154               1005.023542
# 4    Maranhao  2004-05                1.709709               1007.190591
# ..        ...      ...                     ...                       ...
# 223  Maranhao  2022-08                4.772727               1006.657863
# 224  Maranhao  2022-09                0.200000               1006.195972
# 225  Maranhao  2022-10                0.000000               1004.889382
# 226  Maranhao  2022-11                1.460000               1004.611389
# 227  Maranhao  2022-12                3.504000               1004.333602
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                           14133.909320                        26.394489
# 1                           14326.073569                        25.726006
# 2                           16206.420635                        26.222715
# 3                           14560.392000                        26.133611
# 4                           18655.792899                        27.382930
# ..                                   ...                              ...
# 223                          1556.724731                        26.441935
# 224                          1637.339037                        26.995694
# 225                          1620.601241                        27.533468
# 226                          1432.079337                        26.903472
# 227                          1435.703491                        27.234677
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     23.263105                  83.682796         2.229906
# 1                     23.474497                  87.913793         1.780675
# 2                     23.829032                  87.298387         1.781183
# 3                     23.849375                  87.864583         1.541389
# 4                     23.892944                  82.006720         2.109745
# ..                          ...                        ...              ...
# 223                   22.871573                  81.620968         1.732863
# 224                   22.495417                  77.036111         2.406944
# 225                   22.496774                  74.706989         2.648118
# 226                   22.859167                  79.286111         1.992778
# 227                   22.828091                  77.706989         2.127823
#
#      Year
# 0    2004
# 1    2004
# 2    2004
# 3    2004
# 4    2004
# ..    ...
# 223  2022
# 224  2022
# 225  2022
# 226  2022
# 227  2022
#
# [228 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
