# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('sergipe_variacao_climatica')
df
# Out:
#        State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Sergipe  2004-01                2.126562               1010.900470
# 1    Sergipe  2004-02                1.305263               1012.154023
# 2    Sergipe  2004-03                1.309524               1011.792204
# 3    Sergipe  2004-04                1.751613               1012.526944
# 4    Sergipe  2004-05                1.917647               1014.048925
# ..       ...      ...                     ...                       ...
# 223  Sergipe  2022-08                0.000000               1018.800000
# 224  Sergipe  2022-09                0.891667               1015.987778
# 225  Sergipe  2022-10                3.269231               1014.195497
# 226  Sergipe  2022-11                0.926946               1011.679653
# 227  Sergipe  2022-12                1.394118               1011.639247
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                            1594.666667                        26.641667
# 1                            1344.000000                        27.311638
# 2                             864.362319                        27.576478
# 3                             965.612500                        27.344514
# 4                             964.432432                        26.350806
# ..                                   ...                              ...
# 223                             0.000000                        27.000000
# 224                          1503.932459                        25.746250
# 225                          1548.928642                        26.228898
# 226                          1451.109816                        26.012222
# 227                          1562.921324                        26.227285
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     22.547648                  78.806452         3.338911
# 1                     22.305316                  74.561782         3.443822
# 2                     22.326344                  73.552419         3.473656
# 3                     22.033889                  73.159722         3.040764
# 4                     21.381720                  74.776882         2.524462
# ..                          ...                        ...              ...
# 223                   16.100000                  51.000000         2.000000
# 224                   18.820000                  66.374306         2.297083
# 225                   20.656200                  72.026714         2.770632
# 226                   23.040341                  82.480889         3.081319
# 227                   12.475594                  48.241108         2.907124
#
#      Year
# 0    2004
# 1    2004
# 2    2004
# 3    2004
# 4    2004
# ..    ...
# 223  2022
# 224  2022
# 225  2022
# 226  2022
# 227  2022
#
# [228 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
