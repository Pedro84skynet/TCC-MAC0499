# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    plt.figure(figsize=(10, 6)) 
    plt.plot(df['Date'], df[column], color=color)  
    plt.xlabel('Date')  
    plt.ylabel(column)  
    plt.title(f'Plot of {column} over time') 
    plt.grid(True)  
    plt.xticks(rotation=45)  
    plt.tight_layout()  
    plt.show()

# %%
df = pd.read_csv('rondonia_variacao_climatica')
df
# Out:
#        State  Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0   Rondônia  2008                2.807178               1000.736310
# 1   Rondônia  2009                3.070470               1000.654994
# 2   Rondônia  2010                2.558022               1000.585166
# 3   Rondônia  2011                2.649337               1000.322346
# 4   Rondônia  2012                2.277037               1000.667657
# 5   Rondônia  2013                2.529395                979.507825
# 6   Rondônia  2014                2.835033                979.042489
# 7   Rondônia  2015                2.873597                993.412152
# 8   Rondônia  2016                2.823181                994.355573
# 9   Rondônia  2017                2.743834                996.035360
# 10  Rondônia  2018                2.984576                998.009623
# 11  Rondônia  2019                2.306446               1001.069566
# 12  Rondônia  2020                0.000000                  0.000000
# 13  Rondônia  2021                0.000000                  0.000000
#
#     Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                           1262.768703                        25.738974
# 1                           1208.360207                        25.933253
# 2                           1399.288061                        27.325394
# 3                           1223.392097                        25.756210
# 4                           1324.945828                        25.733493
# 5                           1355.791652                        26.277386
# 6                           1307.695465                        25.972158
# 7                           1294.903244                        27.439743
# 8                           1363.287865                        26.466610
# 9                           1324.031156                        26.992848
# 10                          1335.248437                        26.511159
# 11                          1283.566319                        26.208898
# 12                             0.000000                         0.000000
# 13                             0.000000                         0.000000
#
#     Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)
# 0                    21.620674                  80.517589         1.663786
# 1                    22.379024                  82.640696         1.351832
# 2                    21.554812                  73.886187         0.829172
# 3                    21.961821                  81.189155         1.731781
# 4                    21.644365                  80.609403         1.325808
# 5                    22.099852                  79.726826         1.841929
# 6                    22.217860                  81.544178         1.288716
# 7                    22.619783                  77.114212         1.373716
# 8                    22.076423                  79.315688         1.297569
# 9                    21.542175                  75.298516         1.474332
# 10                   21.509623                  76.548059         1.508048
# 11                   21.695377                  78.148801         0.769703
# 12                    0.000000                   0.000000         0.000000
# 13                    0.000000                   0.000000         0.000000

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
