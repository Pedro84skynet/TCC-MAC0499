# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('ceara_variacao_climatica')
df
# Out:
#      State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Ceara  2004-01                3.676923               1007.488306
# 1    Ceara  2004-02                2.938636               1008.083333
# 2    Ceara  2004-03                4.656075               1007.443414
# 3    Ceara  2004-04                1.342500               1007.974722
# 4    Ceara  2004-05                1.333333               1009.262433
# ..     ...      ...                     ...                       ...
# 223  Ceara  2022-08                0.000000               1010.800067
# 224  Ceara  2022-09                0.466667               1010.450556
# 225  Ceara  2022-10                0.692308               1009.160282
# 226  Ceara  2022-11                0.889655               1008.356111
# 227  Ceara  2022-12                1.005263               1008.105040
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                            5898.707483                        26.704032
# 1                           12705.160976                        26.266164
# 2                            1099.519231                        26.843548
# 3                            1205.255814                        27.048333
# 4                           13215.915254                        27.333669
# ..                                   ...                              ...
# 223                          1385.004271                        26.620968
# 224                          1440.491731                        27.225694
# 225                          1475.427182                        27.812836
# 226                          1386.568608                        27.693194
# 227                          1346.331017                        27.943011
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     22.810887                  80.118280         2.318616
# 1                     22.930963                  82.681753         2.055891
# 2                     23.071505                  80.767473         2.345565
# 3                     23.054236                  79.681944         2.335625
# 4                     22.664315                  76.450269         2.683468
# ..                          ...                        ...              ...
# 223                   19.779435                  67.854167         2.609946
# 224                   20.169792                  66.560417         3.137361
# 225                   20.510887                  65.676075         3.293280
# 226                   21.063750                  68.198611         2.536250
# 227                   21.161694                  67.530242         2.771774
#
#      Year
# 0    2004
# 1    2004
# 2    2004
# 3    2004
# 4    2004
# ..    ...
# 223  2022
# 224  2022
# 225  2022
# 226  2022
# 227  2022
#
# [228 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
