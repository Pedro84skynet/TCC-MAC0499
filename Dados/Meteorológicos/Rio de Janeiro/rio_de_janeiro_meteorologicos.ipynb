# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('rio_de_janeiro_variacao_climatica')
df
# Out:
#               State     Date  Precipitation (mm/day)  \
# 0    Rio de Janeiro  2003-01                3.602469
# 1    Rio de Janeiro  2003-02                3.000000
# 2    Rio de Janeiro  2003-03                1.939167
# 3    Rio de Janeiro  2003-04                2.775000
# 4    Rio de Janeiro  2003-05                0.675117
# ..              ...      ...                     ...
# 235  Rio de Janeiro  2022-08                1.081250
# 236  Rio de Janeiro  2022-09                1.598601
# 237  Rio de Janeiro  2022-10                1.429412
# 238  Rio de Janeiro  2022-11                1.704110
# 239  Rio de Janeiro  2022-12                2.941732
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 0                 1008.318347                          1242.981530
# 1                 1009.843676                          1741.859079
# 2                 1010.931519                          1219.670455
# 3                 1013.024931                          1298.524079
# 4                 1014.768011                          1121.165266
# ..                        ...                                  ...
# 235               1017.125806                          1045.947917
# 236               1015.451528                           911.786534
# 237               1012.023790                          1033.220862
# 238               1011.842500                          1101.906926
# 239               1008.983737                          1016.391116
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 0                          26.070094                   22.094086
# 1                          27.612351                   21.021205
# 2                          25.269892                   21.011425
# 3                          24.041111                   19.890764
# 4                          20.961425                   16.795228
# ..                               ...                         ...
# 235                        20.460215                   16.144892
# 236                        19.915000                   16.745139
# 237                        23.658468                   20.557392
# 238                        22.370278                   19.611667
# 239                        24.205914                   21.259812
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Year
# 0                    80.715726         0.014449  2003
# 1                    71.360119         0.089137  2003
# 2                    79.372312         0.200874  2003
# 3                    79.666667         0.819236  2003
# 4                    79.618952         0.794892  2003
# ..                         ...              ...   ...
# 235                  80.139785         0.814919  2022
# 236                  84.962500         0.641806  2022
# 237                  84.788978         0.654839  2022
# 238                  86.180556         0.656667  2022
# 239                  85.458333         0.694489  2022
#
# [240 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
