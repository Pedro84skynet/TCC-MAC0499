# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('rio_grande_do_sul_variacao_climatica')
df
# Out:
#                  State     Date  Precipitation (mm/day)  \
# 0    Rio Grande do Sul  2001-01                3.071698
# 1    Rio Grande do Sul  2001-02                2.638889
# 2    Rio Grande do Sul  2001-03                3.242105
# 3    Rio Grande do Sul  2001-04                2.575701
# 4    Rio Grande do Sul  2001-05                0.952632
# ..                 ...      ...                     ...
# 259  Rio Grande do Sul  2022-08                1.248193
# 260  Rio Grande do Sul  2022-09                1.262069
# 261  Rio Grande do Sul  2022-10                1.551613
# 262  Rio Grande do Sul  2022-11                1.186364
# 263  Rio Grande do Sul  2022-12                1.514286
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 0                 1006.503763                          1419.159459
# 1                 1006.558631                          1389.144357
# 2                 1007.544489                          1301.914787
# 3                 1010.346736                           946.403361
# 4                 1011.361817                           715.570513
# ..                        ...                                  ...
# 259               1014.140054                           993.337989
# 260               1012.509722                          1231.342377
# 261               1009.169892                          1268.605201
# 262               1010.782708                          1638.388000
# 263               1005.588172                          1680.538829
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 0                          26.574194                   20.143011
# 1                          25.691071                   20.977976
# 2                          24.981922                   20.246707
# 3                          21.042014                   17.446458
# 4                          16.924236                   13.691220
# ..                               ...                         ...
# 259                        15.152285                   11.112500
# 260                        16.522778                   11.852361
# 261                        19.038374                   14.158737
# 262                        20.965347                   14.856181
# 263                        24.070430                   17.676277
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Year
# 0                    69.670699         1.915323  2001
# 1                    76.424107         1.916518  2001
# 2                    76.416667         1.629906  2001
# 3                    81.131250         1.455347  2001
# 4                    81.853336         1.491116  2001
# ..                         ...              ...   ...
# 259                  78.732527         1.365726  2022
# 260                  75.623611         1.560833  2022
# 261                  75.532258         1.675605  2022
# 262                  70.758333         1.714931  2022
# 263                  69.810484         1.718884  2022
#
# [264 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [5], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
