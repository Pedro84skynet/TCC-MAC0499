# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('sao_paulo_variacao_climatica')
df
# Out:
#          State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    São Paulo  2003-01                0.000000                836.000000
# 1    São Paulo  2003-02                0.000000                836.000000
# 2    São Paulo  2003-03                0.000000                836.034441
# 3    São Paulo  2003-04                0.000000                837.913292
# 4    São Paulo  2003-05                0.575000                838.471513
# ..         ...      ...                     ...                       ...
# 235  São Paulo  2022-08                0.000000                838.168280
# 236  São Paulo  2022-09                0.000000                836.747639
# 237  São Paulo  2022-10                0.000000                835.958199
# 238  São Paulo  2022-11                2.657971                834.635000
# 239  São Paulo  2022-12                1.509483                833.675672
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                               0.000000                        13.100000
# 1                               0.000000                        13.100000
# 2                               0.000000                        13.126205
# 3                               0.000000                        14.555766
# 4                            1325.367442                        13.523726
# ..                                   ...                              ...
# 235                            35.810714                        11.760887
# 236                            22.540741                        13.407500
# 237                            89.263636                        16.209677
# 238                          1021.270370                        13.996806
# 239                             0.000000                        16.038172
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     12.000000                  93.000000         1.100000
# 1                     12.000000                  93.000000         1.100000
# 2                     11.931653                  92.640618         1.226532
# 3                      8.946875                  73.035211         2.923019
# 4                      6.606653                  66.100844         2.952266
# ..                          ...                        ...              ...
# 235                    6.877285                  74.848118         1.447177
# 236                    8.960694                  77.536111         1.367917
# 237                   12.147715                  79.204301         1.416801
# 238                   10.997361                  83.616667         1.493681
# 239                   13.396102                  85.797043         1.400000
#
#      Year
# 0    2003
# 1    2003
# 2    2003
# 3    2003
# 4    2003
# ..    ...
# 235  2022
# 236  2022
# 237  2022
# 238  2022
# 239  2022
#
# [240 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
