# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('mato_grosso_variacao_climatica')
df
# Out:
#            State     Date  Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# 0    Mato Grosso  2003-01                1.858824                997.241801
# 1    Mato Grosso  2003-02                2.454839                993.513170
# 2    Mato Grosso  2003-03                1.327835                993.184274
# 3    Mato Grosso  2003-04                2.106897                994.628472
# 4    Mato Grosso  2003-05                2.463158                995.579503
# ..           ...      ...                     ...                       ...
# 235  Mato Grosso  2022-08                2.475000                992.983938
# 236  Mato Grosso  2022-09                3.888235                990.825833
# 237  Mato Grosso  2022-10                1.811111                989.728629
# 238  Mato Grosso  2022-11                1.790625                989.431458
# 239  Mato Grosso  2022-12                1.908929                987.685282
#
#      Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# 0                            1401.032258                        26.809274
# 1                            1387.853211                        26.571875
# 2                            1257.000000                        26.511694
# 3                            1184.886598                        26.098194
# 4                            1278.666667                        25.165457
# ..                                   ...                              ...
# 235                          1549.598138                        26.644758
# 236                          1434.712339                        29.032292
# 237                          1457.725735                        28.630444
# 238                          1827.549364                        27.898611
# 239                          1469.341727                        28.350067
#
#      Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# 0                     22.842204                  80.055108         2.563575
# 1                     22.047024                  77.836310         1.958780
# 2                     22.400806                  79.559140         1.846102
# 3                     21.160000                  76.741667         1.784583
# 4                     18.938105                  71.823253         1.683669
# ..                          ...                        ...              ...
# 235                   11.357728                  43.565188         1.538239
# 236                   15.350556                  47.336806         1.732361
# 237                   19.288642                  59.586694         1.644153
# 238                   15.251944                  50.245833         1.643681
# 239                   20.237366                  63.321909         3.186223
#
#      Year
# 0    2003
# 1    2003
# 2    2003
# 3    2003
# 4    2003
# ..    ...
# 235  2022
# 236  2022
# 237  2022
# 238  2022
# 239  2022
#
# [240 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
