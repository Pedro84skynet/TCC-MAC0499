# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('rio_grande_do_norte_variacao_climatica')
df
# Out:
#                    State     Date  Precipitation (mm/day)  \
# 0    Rio Grande do Norte  2004-01                0.200000
# 1    Rio Grande do Norte  2004-02                2.861538
# 2    Rio Grande do Norte  2004-03                3.175676
# 3    Rio Grande do Norte  2004-04                2.028409
# 4    Rio Grande do Norte  2004-05                1.561364
# ..                   ...      ...                     ...
# 223  Rio Grande do Norte  2022-08                1.811111
# 224  Rio Grande do Norte  2022-09                0.986047
# 225  Rio Grande do Norte  2022-10                1.013793
# 226  Rio Grande do Norte  2022-11                0.941176
# 227  Rio Grande do Norte  2022-12                0.000000
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 0                 1008.000000                             0.000000
# 1                 1005.968678                           943.759259
# 2                 1005.492608                           989.039474
# 3                 1005.973056                           961.164557
# 4                 1007.400067                           874.868687
# ..                        ...                                  ...
# 223               1009.118145                          1511.553699
# 224               1008.710972                          1764.426343
# 225               1007.381452                          1749.245564
# 226               1006.364146                          1733.574157
# 227               1005.803380                          2105.225000
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 0                          24.900000                   23.100000
# 1                          26.976580                   22.771695
# 2                          27.274798                   22.425538
# 3                          26.940069                   22.512083
# 4                          26.234341                   22.108938
# ..                               ...                         ...
# 223                        24.964785                   21.184677
# 224                        25.771667                   21.562639
# 225                        26.745968                   22.208468
# 226                        27.000054                   22.346650
# 227                        28.237716                   22.587920
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Year
# 0                    90.000000         0.900000  2004
# 1                    78.301006         4.214799  2004
# 2                    75.395161         4.568683  2004
# 3                    77.284722         4.385069  2004
# 4                    78.656586         4.043212  2004
# ..                         ...              ...   ...
# 223                  80.358871         4.241801  2022
# 224                  78.104167         4.420833  2022
# 225                  76.586022         4.608602  2022
# 226                  75.878032         3.608872  2022
# 227                  71.558222         4.046186  2022
#
# [228 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
