# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
def plot_column(df, column, color):
    df['Year'] = pd.to_datetime(df['Date']).dt.year
    plt.figure(figsize=(10, 6))
    plt.plot(df['Date'], df[column], color=color)
    plt.xlabel('Date')
    plt.ylabel(column)
    plt.title(f'{column} over time')
    plt.xticks(df['Date'][::12], rotation=45, ha='right')  # Display year at 12-month intervals
    plt.grid(True)
    plt.show()

# %%
df = pd.read_csv('santa_catarina_variacao_climatica')
df
# Out:
#               State     Date  Precipitation (mm/day)  \
# 0    Santa Catarina  2004-01                3.344330
# 1    Santa Catarina  2004-02                2.838806
# 2    Santa Catarina  2004-03                2.977143
# 3    Santa Catarina  2004-04                1.980769
# 4    Santa Catarina  2004-05                1.585714
# ..              ...      ...                     ...
# 223  Santa Catarina  2022-08                2.037500
# 224  Santa Catarina  2022-09                1.058586
# 225  Santa Catarina  2022-10                1.841071
# 226  Santa Catarina  2022-11                1.186957
# 227  Santa Catarina  2022-12                3.265248
#
#      Atmospheric Pressure(mB)  Global Radiation - Daylight (Kj/m²)  \
# 0                 1011.970632                          1342.657143
# 1                 1013.360057                          1589.460705
# 2                 1014.232930                          1330.583979
# 3                 1017.660270                          1208.881250
# 4                 1026.026553                           879.226562
# ..                        ...                                  ...
# 223               1020.272849                          1037.926389
# 224               1018.699167                          1165.223298
# 225               1015.058871                          1173.582517
# 226               1016.497222                          1497.051049
# 227               1011.938978                          1464.390066
#
#      Air Temperature - Dry Bulb (°C)  Dew Point Temperature (°C)  \
# 0                          24.269624                   19.437097
# 1                          24.140158                   19.081753
# 2                          23.415793                   18.480040
# 3                          23.499296                   19.296842
# 4                          19.303033                   13.974360
# ..                               ...                         ...
# 223                        17.072849                   13.019758
# 224                        17.688194                   12.860833
# 225                        20.386290                   16.172849
# 226                        21.332639                   15.618333
# 227                        23.681586                   18.864785
#
#      Air Relative Humidity (%)  Wind Gust (m/s)  Year
# 0                    75.148522         2.329503  2004
# 1                    74.030891         2.412069  2004
# 2                    74.351478         2.316196  2004
# 3                    77.664387         1.848044  2004
# 4                    72.051938         2.187444  2004
# ..                         ...              ...   ...
# 223                  78.120968         1.594489  2022
# 224                  74.781944         1.740556  2022
# 225                  77.838710         1.812231  2022
# 226                  71.493056         2.135000  2022
# 227                  75.655914         1.248118  2022
#
# [228 rows x 10 columns]

# %%
colors = ['#FF0000', '#FF7F00', '#FFFF00', '#00FF00', '#0000FF', '#4B0082', '#8B00FF', '#9400D3', '#FF00FF']
for i, column in enumerate(df.columns):
    if i > 1:
        plot_column(df, column, color=colors[i])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [4], line 4
#       2 for i, column in enumerate(df.columns):
#       3     if i > 1:
# ----> 4         plot_column(df, column, color=colors[i])
#
# IndexError: list index out of range
