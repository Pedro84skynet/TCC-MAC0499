# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import csv
import glob

# %%
plt.rcParams['figure.max_open_warning'] = 91

# %%
def plot_columns(df):
    colors = plt.cm.tab20(range(df.shape[1]))  

    for i, column in enumerate(df.columns):
        color = colors[i % 24]

        plt.figure()
        plt.plot(df.index, df[column], color=color)
        plt.xlabel('Ano')
        plt.ylabel('Valor')
        plt.title(column)

    plt.show()

# %%
def concatenador():
    df_list = []
    csv_files = glob.glob("*.csv")
    for file in csv_files:
        df = pd.read_csv(file, index_col=0)  
        df_list.append(df)

    df_concatenated = pd.concat(df_list,axis=1)
    return df_concatenated

# %%
df_input = concatenador()
df_input
# Out:
#       Acre - IDH Renda  Acre - IDH  Acre - PIB Estadual  \
# Ano
# 2014          0.660516    0.711115         8.560896e+06
# 2015          0.663153    0.720255         8.597116e+06
# 2016          0.662167    0.720460         8.620855e+06
# 2017          0.662364    0.720230         8.632052e+06
# 2018          0.663033    0.720978         8.619421e+06
# 2019          0.661854    0.719885         8.563064e+06
# 2020          0.661296    0.718147         8.474525e+06
# 2021          0.660686    0.715615         8.328315e+06
# 2022          0.661203    0.716125         8.150141e+06
#
#       Acre - PIB Construção Civil  Acre - PIB Per Capita  \
# Ano
# 2014                400704.121188               9.343267
# 2015                391942.316578               9.284504
# 2016                389049.090551               9.247193
# 2017                389052.079088               9.235469
# 2018                391132.683164               9.229845
# 2019                393404.510680               9.229435
# 2020                395956.006706               9.239313
# 2021                399296.137980               9.262962
# 2022                403056.753694               9.289289
#
#       Acre - PIB Preços de Mercado  Contratação Comercial (Bi R$)  \
# Ano
# 2014                  6.852462e+06                   5.676413e+08
# 2015                  6.825760e+06                   5.179392e+08
# 2016                  6.809907e+06                   4.524144e+08
# 2017                  6.808242e+06                   4.213689e+08
# 2018                  6.804838e+06                   4.166580e+08
# 2019                  6.792501e+06                   4.462625e+08
# 2020                  6.780171e+06                   5.489412e+08
# 2021                  6.763503e+06                   6.638811e+08
# 2022                  6.741052e+06                   7.010332e+08
#
#       Contratação  Home equity (Bi R$)  Contratação  Livre (Bi R$)  \
# Ano
# 2014                      2.779340e+09                1.954361e+10
# 2015                      2.561731e+09                1.327596e+10
# 2016                      2.516859e+09                1.011370e+10
# 2017                      2.497710e+09                8.456309e+09
# 2018                      2.797145e+09                7.937760e+09
# 2019                      3.484252e+09                1.091282e+10
# 2020                      4.114911e+09                1.625333e+10
# 2021                      4.421848e+09                1.933031e+10
# 2022                      4.533216e+09                1.997888e+10
#
#       Contratação  FGTS (Bi R$)  ...  Atmospheric Pressure(mB)  \
# Ano                              ...
# 2014               4.143397e+10  ...                985.694959
# 2015               4.469706e+10  ...                986.021421
# 2016               4.640544e+10  ...                985.952489
# 2017               4.607888e+10  ...                987.415055
# 2018               4.467878e+10  ...                990.300474
# 2019               4.379096e+10  ...                991.748979
# 2020               4.320994e+10  ...                990.943430
# 2021               4.488070e+10  ...                990.216809
# 2022               4.699319e+10  ...                990.175184
#
#       Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# Ano
# 2014                          1230.934473                        26.457083
# 2015                          1278.252041                        26.043363
# 2016                          1333.799567                        25.936106
# 2017                          1385.250388                        26.527832
# 2018                          1358.141602                        27.126298
# 2019                          1319.203565                        27.958921
# 2020                          1329.282952                        29.233325
# 2021                          1380.754715                        29.633694
# 2022                          1380.835509                        29.449893
#
#       Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# Ano
# 2014                   21.165984                  76.068571         1.660711
# 2015                   21.489384                  78.704494         1.603219
# 2016                   21.376188                  78.087996         1.551043
# 2017                   21.280819                  74.803746         1.421881
# 2018                   21.732628                  74.092935         1.192635
# 2019                   22.407138                  73.297486         0.958636
# 2020                   22.624746                  69.064652         0.790134
# 2021                   22.179792                  66.100954         0.580550
# 2022                   22.067993                  66.491567         0.541832
#
#       Acre - Consumo de Cimento (t)  Acre - Desemprego  \
# Ano
# 2014                     162.799156          11.666939
# 2015                     151.609123          12.139670
# 2016                     148.170166          12.458072
# 2017                     149.734482          12.245790
# 2018                     153.625376          12.148886
# 2019                     164.722314          12.045733
# 2020                     178.233927          11.905311
# 2021                     187.872932          11.817334
# 2022                     191.530787          11.830301
#
#       Acre - Produção de Cimento (t)  Acre - IDH Longevidade
# Ano
# 2014                             0.0                0.796188
# 2015                             0.0                0.808026
# 2016                             0.0                0.807937
# 2017                             0.0                0.807295
# 2018                             0.0                0.806140
# 2019                             0.0                0.804426
# 2020                             0.0                0.802101
# 2021                             0.0                0.800019
# 2022                             0.0                0.801112
#
# [9 rows x 75 columns]

# %%
plot_columns(df_input)

# %%
df_input.to_csv('2014_01_model_input.csv', index=True)
