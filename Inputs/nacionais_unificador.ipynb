# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import csv

# %%
df_imob = pd.read_csv('2014_01_imob.csv')
df_imob.set_index('Ano', inplace=True)
df_ipca = pd.read_csv('2014_01_ipca.csv')
df_ipca.set_index('Ano', inplace=True)
df_nfsp = pd.read_csv('2014_01_nfsp.csv')
df_nfsp.set_index('Ano', inplace=True)
df_selic = pd.read_csv('2014_01_selic.csv')
df_selic.set_index('Ano', inplace=True)

# %%
df_nasc = pd.concat([df_imob, df_ipca, df_nfsp, df_selic], axis=1)
df_nasc = df_nasc[df_nasc.index < 2023]
df_nasc
# Out:
#       Contratação Comercial (Bi R$)  Contratação  Home equity (Bi R$)  \
# Ano
# 2014                   5.676413e+08                      2.779340e+09
# 2015                   5.179392e+08                      2.561731e+09
# 2016                   4.524144e+08                      2.516859e+09
# 2017                   4.213689e+08                      2.497710e+09
# 2018                   4.166580e+08                      2.797145e+09
# 2019                   4.462625e+08                      3.484252e+09
# 2020                   5.489412e+08                      4.114911e+09
# 2021                   6.638811e+08                      4.421848e+09
# 2022                   7.010332e+08                      4.533216e+09
#
#       Contratação  Livre (Bi R$)  Contratação  FGTS (Bi R$)  \
# Ano
# 2014                1.954361e+10               4.143397e+10
# 2015                1.327596e+10               4.469706e+10
# 2016                1.011370e+10               4.640544e+10
# ...

# %%
df_nasc.to_csv('2014_01_dados_nascionais.csv', index=True)
