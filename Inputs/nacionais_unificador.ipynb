# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import csv

# %%
current_year = 2008

# %%
df_imob = pd.read_csv(f'{current_year}_01_imob.csv')
df_imob.set_index('Ano', inplace=True)
df_ipca = pd.read_csv(f'{current_year}_01_ipca.csv')
df_ipca.set_index('Ano', inplace=True)
df_nfsp = pd.read_csv(f'{current_year}_01_nfsp.csv')
df_nfsp.set_index('Ano', inplace=True)
df_selic = pd.read_csv(f'{current_year}_01_selic.csv')
df_selic.set_index('Ano', inplace=True)

# %%
df_nasc = pd.concat([df_imob, df_ipca, df_nfsp, df_selic], axis=1)
df_nasc = df_nasc[df_nasc.index < 2023]
df_nasc
# Out:
#       Contratação Comercial (Bi R$)  Contratação  Home equity (Bi R$)  \
# Ano
# 2008                   5.483335e+08                      2.546644e+09
# 2009                   5.302764e+08                      2.679945e+09
# 2010                   5.046425e+08                      2.891930e+09
# 2011                   4.854622e+08                      3.091988e+09
# 2012                   4.867661e+08                      3.189506e+09
# 2013                   5.225848e+08                      3.093872e+09
# 2014                   5.676413e+08                      2.779340e+09
# 2015                   5.179392e+08                      2.561731e+09
# 2016                   4.524144e+08                      2.516859e+09
# 2017                   4.213689e+08                      2.497710e+09
# 2018                   4.166580e+08                      2.797145e+09
# 2019                   4.462625e+08                      3.484252e+09
# ...

# %%
df_nasc.to_csv(f'{current_year}_01_dados_nascionais.csv', index=True)
