# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import csv
import glob

# %%
plt.rcParams['figure.max_open_warning'] = 91

# %%
def plot_columns(df):
    colors = plt.cm.tab20(range(df.shape[1]))  

    for i, column in enumerate(df.columns):
        color = colors[i % 24]

        plt.figure()
        plt.plot(df.index, df[column], color=color)
        plt.xlabel('Ano')
        plt.ylabel('Valor')
        plt.title(column)

    plt.show()

# %%
def concatenador():
    df_list = []
    csv_files = glob.glob("*.csv")
    for file in csv_files:
        df = pd.read_csv(file, index_col=0)  
        df_list.append(df)

    df_concatenated = pd.concat(df_list,axis=1)
    return df_concatenated

# %%
df_input = concatenador()
df_input
# Out:
#       Goiás - Desemprego  Goiás - Produção de Cimento (t)  \
# Ano
# 2014            9.015756                      1413.139667
# 2015            9.398111                      1402.398186
# 2016            9.378450                      1460.206906
# 2017            8.980786                      1589.529694
# 2018            8.919908                      1731.934560
# 2019            8.947167                      1895.220271
# 2020            8.745410                      2042.474520
# 2021            8.543845                      2103.272798
# 2022            8.559723                      2106.312452
#
#       Goiás - PIB - Estadual  Goiás - PIB - Construção Civil  \
# Ano
# 2014            1.105942e+08                    5.711944e+06
# 2015            1.115113e+08                    5.628820e+06
# 2016            1.120977e+08                    5.573901e+06
# 2017            1.123228e+08                    5.555871e+06
# 2018            1.120752e+08                    5.557505e+06
# 2019            1.115262e+08                    5.575031e+06
# 2020            1.103087e+08                    5.582060e+06
# 2021            1.081897e+08                    5.596945e+06
# 2022            1.056196e+08                    5.612097e+06
#
#       Goiás - PIB - Per Capita  Goiás - PIB - Preços de Mercado  \
# Ano
# 2014                 14.238295                     8.787916e+07
# 2015                 14.206629                     8.784849e+07
# 2016                 14.184179                     8.781949e+07
# 2017                 14.177721                     8.783412e+07
# 2018                 14.162196                     8.772142e+07
# 2019                 14.162109                     8.764907e+07
# 2020                 14.153729                     8.743050e+07
# 2021                 14.151592                     8.707619e+07
# 2022                 14.145783                     8.662341e+07
#
#       Goiás - Consumo de Cimento (t)  Contratação Comercial (Bi R$)  \
# Ano
# 2014                     2700.677734                   5.676413e+08
# 2015                     2486.499407                   5.179392e+08
# 2016                     2365.569752                   4.524144e+08
# 2017                     2339.132479                   4.213689e+08
# 2018                     2340.657615                   4.166580e+08
# 2019                     2439.018856                   4.462625e+08
# 2020                     2582.285931                   5.489412e+08
# 2021                     2676.365067                   6.638811e+08
# 2022                     2712.065368                   7.010332e+08
#
#       Contratação  Home equity (Bi R$)  Contratação  Livre (Bi R$)  ...  \
# Ano                                                                 ...
# 2014                      2.779340e+09                1.954361e+10  ...
# 2015                      2.561731e+09                1.327596e+10  ...
# 2016                      2.516859e+09                1.011370e+10  ...
# 2017                      2.497710e+09                8.456309e+09  ...
# 2018                      2.797145e+09                7.937760e+09  ...
# 2019                      3.484252e+09                1.091282e+10  ...
# 2020                      4.114911e+09                1.625333e+10  ...
# 2021                      4.421848e+09                1.933031e+10  ...
# 2022                      4.533216e+09                1.997888e+10  ...
#
#       Goiás - IDH   Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# Ano
# 2014      0.753127               25.841819                932.468684
# 2015      0.756319               25.709892                932.508663
# 2016      0.756439               26.601698                932.486431
# 2017      0.755752               26.603489                932.515580
# 2018      0.754911               26.164873                932.528575
# 2019      0.753449               27.979477                932.435646
# 2020      0.751580               27.398674                932.273964
# 2021      0.750997               25.252347                932.133605
# 2022      0.752269               24.960871                932.102271
#
#       Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# Ano
# 2014                          1423.836782                        23.878739
# 2015                          1430.027526                        24.014961
# 2016                          1433.688880                        23.900472
# 2017                          1426.852240                        23.876158
# 2018                          1418.987936                        23.962596
# 2019                          1418.536549                        23.979123
# 2020                          1420.789270                        23.899712
# 2021                          1418.048489                        23.854888
# 2022                          1415.895918                        23.836880
#
#       Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# Ano
# 2014                   15.683323                  65.088818         1.241766
# 2015                   15.540525                  64.054609         1.245195
# 2016                   15.251199                  63.441573         1.236011
# 2017                   15.213263                  63.423776         1.188108
# 2018                   15.306996                  63.483723         1.129020
# 2019                   15.056576                  62.750681         1.083531
# 2020                   14.857114                  62.358179         1.038939
# 2021                   14.689557                  61.933270         1.020945
# 2022                   14.524480                  61.463613         1.027329
#
#       Goiás - IDH Longevidade  Goiás - IDH Renda
# Ano
# 2014                 0.779847           0.736954
# 2015                 0.786917           0.728616
# 2016                 0.784364           0.728399
# 2017                 0.781307           0.728799
# 2018                 0.777698           0.728236
# 2019                 0.773489           0.727621
# 2020                 0.768624           0.727495
# 2021                 0.769135           0.727995
# 2022                 0.773511           0.729267
#
# [9 rows x 75 columns]

# %%
plot_columns(df_input)

# %%
df_input.to_csv('2014_01_model_input.csv', index=True)
