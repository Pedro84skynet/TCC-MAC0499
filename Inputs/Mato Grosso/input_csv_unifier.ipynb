# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import csv
import glob

# %%
plt.rcParams['figure.max_open_warning'] = 91

# %%
def plot_columns(df):
    colors = plt.cm.tab20(range(df.shape[1]))  

    for i, column in enumerate(df.columns):
        color = colors[i % 24]

        plt.figure()
        plt.plot(df.index, df[column], color=color)
        plt.xlabel('Ano')
        plt.ylabel('Valor')
        plt.title(column)

    plt.show()

# %%
def concatenador():
    df_list = []
    csv_files = glob.glob("*.csv")
    for file in csv_files:
        df = pd.read_csv(file, index_col=0)  
        df_list.append(df)

    df_concatenated = pd.concat(df_list,axis=1)
    return df_concatenated

# %%
df_input = concatenador()
df_input
# Out:
#       Mato Grosso - Desemprego  Mato Grosso - PIB - Estadual  \
# Ano
# 2014                  7.495401                  7.450695e+07
# 2015                  7.838256                  7.552129e+07
# 2016                  7.730867                  7.631332e+07
# 2017                  7.251143                  7.659073e+07
# 2018                  7.109465                  7.676559e+07
# 2019                  7.037991                  7.645988e+07
# 2020                  6.871142                  7.584496e+07
# 2021                  6.623657                  7.372752e+07
# 2022                  6.630925                  7.119278e+07
#
#       Mato Grosso - PIB - Construção Civil  Mato Grosso - PIB - Per Capita  \
# Ano
# 2014                          2.898181e+06                       17.765377
# 2015                          2.867943e+06                       17.804826
# 2016                          2.837856e+06                       17.844276
# 2017                          2.826355e+06                       17.841399
# 2018                          2.824325e+06                       17.858303
# 2019                          2.828969e+06                       17.844789
# 2020                          2.832984e+06                       17.835880
# 2021                          2.820526e+06                       17.690471
# 2022                          2.804678e+06                       17.513528
#
#       Mato Grosso - PIB - Preços de Mercado  Mato Grosso - IDH Educacao  \
# Ano
# 2014                           5.559725e+07                    0.746518
# 2015                           5.583983e+07                    0.758124
# 2016                           5.605555e+07                    0.757317
# 2017                           5.610212e+07                    0.756528
# 2018                           5.618080e+07                    0.756485
# 2019                           5.610350e+07                    0.755802
# 2020                           5.599389e+07                    0.754420
# 2021                           5.530452e+07                    0.753458
# 2022                           5.446856e+07                    0.753045
#
#       Mato Grosso - IDH Renda  Contratação Comercial (Bi R$)  \
# Ano
# 2014                 0.737561                   5.676413e+08
# 2015                 0.732393                   5.179392e+08
# 2016                 0.732701                   4.524144e+08
# 2017                 0.733401                   4.213689e+08
# 2018                 0.733438                   4.166580e+08
# 2019                 0.732478                   4.462625e+08
# 2020                 0.731976                   5.489412e+08
# 2021                 0.731701                   6.638811e+08
# 2022                 0.732764                   7.010332e+08
#
#       Contratação  Home equity (Bi R$)  Contratação  Livre (Bi R$)  ...  \
# Ano                                                                 ...
# 2014                      2.779340e+09                1.954361e+10  ...
# 2015                      2.561731e+09                1.327596e+10  ...
# 2016                      2.516859e+09                1.011370e+10  ...
# 2017                      2.497710e+09                8.456309e+09  ...
# 2018                      2.797145e+09                7.937760e+09  ...
# 2019                      3.484252e+09                1.091282e+10  ...
# 2020                      4.114911e+09                1.625333e+10  ...
# 2021                      4.421848e+09                1.933031e+10  ...
# 2022                      4.533216e+09                1.997888e+10  ...
#
#       Mato Grosso - IDH Longevidade  Mato Grosso - Consumo de Cimento (t)  \
# Ano
# 2014                       0.782759                           1314.521547
# 2015                       0.791129                           1224.515882
# 2016                       0.788868                           1215.412396
# 2017                       0.786038                           1279.457390
# 2018                       0.782587                           1355.958836
# 2019                       0.778458                           1475.848294
# 2020                       0.773591                           1622.441130
# 2021                       0.774008                           1745.453251
# 2022                       0.778009                           1798.169562
#
#       Precipitation (mm/day)  Atmospheric Pressure(mB)  \
# Ano
# 2014               33.403862                985.582958
# 2015               31.029765                985.297803
# 2016               27.875013                985.139748
# 2017               26.025417                985.051490
# 2018               26.864064                986.130627
# 2019               27.060953                988.002188
# 2020               26.703448                989.342831
# 2021               25.957132                989.869529
# 2022               25.101402                989.986809
#
#       Global Radiation - Daylight (Kj/m²)  Air Temperature - Dry Bulb (°C)  \
# Ano
# 2014                           728.555092                        26.792583
# 2015                           631.112819                        26.741398
# 2016                           546.211949                        26.647262
# 2017                           572.018116                        26.728560
# 2018                           790.527175                        27.131978
# 2019                          1086.573235                        27.719471
# 2020                          1296.495701                        27.842739
# 2021                          1388.381414                        27.804463
# 2022                          1412.105050                        27.774281
#
#       Dew Point Temperature (°C)  Air Relative Humidity (%)  Wind Gust (m/s)  \
# Ano
# 2014                   18.998037                  66.249639         1.689375
# 2015                   18.889658                  66.109773         1.670487
# 2016                   18.703122                  65.821838         1.617712
# 2017                   18.583504                  65.279143         1.559939
# 2018                   18.283627                  63.192140         1.527134
# 2019                   17.709442                  59.441754         1.529612
# 2020                   17.441574                  57.842076         1.547261
# 2021                   17.298090                  57.234541         1.600142
# 2022                   17.132150                  56.722192         1.639477
#
#       Mato Grosso - IDH
# Ano
# 2014           0.755153
# 2015           0.759897
# 2016           0.758979
# 2017           0.758068
# 2018           0.756983
# 2019           0.755072
# 2020           0.752897
# 2021           0.752615
# 2022           0.754125
#
# [9 rows x 75 columns]

# %%
plot_columns(df_input)

# %%
df_input.to_csv('2014_01_model_input.csv', index=True)
